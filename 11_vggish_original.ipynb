# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import librosa
from tqdm import tqdm_notebook as tqdm
import json
import pandas as pd
import pickle
import os
import h5py
import collections as cl
from ast import literal_eval
import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, roc_auc_score, average_precision_score
from sklearn.preprocessing import StandardScaler
import random
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
param_grid = {'C': [10**k for k in range(-10, 6, 2)]}  
scoring = 'roc_auc'; cv = 3; random_state=42
random.seed(random_state)

# %%
with open("genre_map.json", "r") as f: # only consider 10 classes of Openmic dataset
    genre_map = json.load(f)
aligned_genre = list(genre_map)[:-1]

with open("instrument_map.json", "r") as f: # only consider 10 classes of Openmic dataset
    instrument_map = json.load(f)

# %%
# use a Pandas DataFrame to record all results and save into a csv file later
result_all = pd.DataFrame({'instrument': [],
                          'train_set': [],
                          'test_set': [],
                          'precision': [],
                          'recall': [],
                          'f1-score': [],
                          'support': [],
                          'accuracy': [],
                          'roc_auc': [],
                          'ap': [],
                          'embedding': [],
                         })

# %% [markdown]
# # Load embeddings and align classes

# %%
embedding = 'vggish'
debias_method = ''

# load embeddings
embeddings = h5py.File("embeddings.h5", "r")

# %%
###### IRMAS data ######
feature = np.array(embeddings["irmas"][embedding]["features"])
keys_ori = np.array(embeddings["irmas"][embedding]["keys"])
key_clip = np.unique(keys_ori)

feature_clip = []

for key in tqdm(key_clip):
    feature_clip.append(np.mean(feature[keys_ori[:]==key,:],axis=0))
    
feature_clip = np.array(feature_clip)
print(feature_clip.shape, key_clip.shape)
# Out:
#   0%|          | 0/6705 [00:00<?, ?it/s]
# (6705, 128) (6705,)

# %%
def load_feature(meta, feature_clip, key_clip):
    key_train = list(meta.loc[(meta['split'] == 'train')]['file_name'])
    key_test = list(meta.loc[(meta['split'] == 'test')]['file_name'])

    idx_train = [list(key_clip).index(item) for item in key_train]
    idx_test = [list(key_clip).index(item) for item in key_test]
   
    # cast the idx_* arrays to numpy structures
    idx_train = np.asarray(idx_train)
    idx_test = np.asarray(idx_test)

    # use the split indices to partition the features, labels, and masks
    X_train = feature_clip[idx_train,:]
    X_test = feature_clip[idx_test]

    Y_train = meta.loc[(meta['split'] == 'train')]['instrument'].values
    Y_test = meta.loc[(meta['split'] == 'test')]['instrument'].values

    genre_train = meta.loc[(meta['split'] == 'train')]['genre'].values
    genre_test = meta.loc[(meta['split'] == 'test')]['genre'].values

    return (X_train, Y_train), (X_test, Y_test), (genre_train, genre_test)

# %%
A_meta = pd.read_csv("A_meta.csv")
(X_train_A, Y_train_A), (X_test_A, Y_test_A), (genre_train_A, genre_test_A) = load_feature(A_meta, feature_clip, key_clip)
B_meta = pd.read_csv("B_meta.csv")
(X_train_B, Y_train_B), (X_test_B, Y_test_B), (genre_train_B, genre_test_B) = load_feature(B_meta, feature_clip, key_clip)

# %% [markdown]
# # A -> A

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'A', 'A' 

globals()['models_' + train_set_name] = dict()

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_A
    Y_train_inst = Y_train_A_inst
    X_test_inst = X_test_A
    Y_test_inst = Y_test_A_inst

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]
    
    # store the classifier in the model dictionary
    globals()['models_' + train_set_name][instrument] = clf

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)

with open('models/models_' + train_set_name + '_' + embedding + debias_method + '.pickle', 'wb') as fdesc:
    pickle.dump(globals()['models_'+train_set_name], fdesc)
# Out:
# ----------------------------------------------------
# cel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.91      0.95       728
#         True       0.25      0.70      0.37        30
#
#     accuracy                           0.91       758
#    macro avg       0.62      0.81      0.66       758
# weighted avg       0.96      0.91      0.93       758
#
# ROC-AUC = 0.923		AP = 0.466
# ----------------------------------------------------
# cla
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.86      0.92       723
#         True       0.23      0.86      0.37        35
#
#     accuracy                           0.86       758
#    macro avg       0.61      0.86      0.65       758
# weighted avg       0.96      0.86      0.90       758
#
# ROC-AUC = 0.935		AP = 0.543
# ----------------------------------------------------
# flu
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.86      0.92       714
#         True       0.25      0.75      0.38        44
#
#     accuracy                           0.86       758
#    macro avg       0.62      0.81      0.65       758
# weighted avg       0.94      0.86      0.89       758
#
# ROC-AUC = 0.884		AP = 0.597
# ----------------------------------------------------
# gac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.92      0.95       660
#         True       0.64      0.91      0.75        98
#
#     accuracy                           0.92       758
#    macro avg       0.81      0.92      0.85       758
# weighted avg       0.94      0.92      0.93       758
#
# ROC-AUC = 0.961		AP = 0.859
# ----------------------------------------------------
# gel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.87      0.92       628
#         True       0.58      0.87      0.69       130
#
#     accuracy                           0.87       758
#    macro avg       0.77      0.87      0.80       758
# weighted avg       0.90      0.87      0.88       758
#
# ROC-AUC = 0.934		AP = 0.788
# ----------------------------------------------------
# org
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.85      0.92       684
#         True       0.40      0.92      0.56        74
#
#     accuracy                           0.86       758
#    macro avg       0.69      0.88      0.74       758
# weighted avg       0.93      0.86      0.88       758
#
# ROC-AUC = 0.937		AP = 0.579
# ----------------------------------------------------
# pia
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.90      0.94       719
#         True       0.30      0.82      0.44        39
#
#     accuracy                           0.89       758
#    macro avg       0.65      0.86      0.69       758
# weighted avg       0.95      0.89      0.92       758
#
# ROC-AUC = 0.925		AP = 0.580
# ----------------------------------------------------
# sax
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.86      0.92       723
#         True       0.20      0.74      0.32        35
#
#     accuracy                           0.85       758
#    macro avg       0.60      0.80      0.62       758
# weighted avg       0.95      0.85      0.89       758
#
# ROC-AUC = 0.841		AP = 0.310
# ----------------------------------------------------
# tru
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.83      0.90       717
#         True       0.23      0.90      0.37        41
#
#     accuracy                           0.83       758
#    macro avg       0.61      0.87      0.64       758
# weighted avg       0.95      0.83      0.87       758
#
# ROC-AUC = 0.938		AP = 0.625
# ----------------------------------------------------
# vio
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.39      0.56       712
#         True       0.08      0.87      0.15        46
#
#     accuracy                           0.42       758
#    macro avg       0.53      0.63      0.36       758
# weighted avg       0.92      0.42      0.53       758
#
# ROC-AUC = 0.820		AP = 0.462
# ----------------------------------------------------
# voi
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.95      0.96       572
#         True       0.86      0.93      0.90       186
#
#     accuracy                           0.95       758
#    macro avg       0.92      0.94      0.93       758
# weighted avg       0.95      0.95      0.95       758
#
# ROC-AUC = 0.980		AP = 0.953

# %% [markdown]
# # A -> B

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'A', 'B' 

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_A
    Y_train_inst = Y_train_A_inst
    X_test_inst = X_test_B
    Y_test_inst = Y_test_B_inst

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
# Out:
# ----------------------------------------------------
# cel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.88      0.93       867
#         True       0.33      0.78      0.46        68
#
#     accuracy                           0.87       935
#    macro avg       0.66      0.83      0.70       935
# weighted avg       0.93      0.87      0.89       935
#
# ROC-AUC = 0.910		AP = 0.545
# ----------------------------------------------------
# cla
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.62      0.76       843
#         True       0.19      0.83      0.31        92
#
#     accuracy                           0.64       935
#    macro avg       0.58      0.72      0.53       935
# weighted avg       0.89      0.64      0.71       935
#
# ROC-AUC = 0.795		AP = 0.351
# ----------------------------------------------------
# flu
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.80      0.88       864
#         True       0.26      0.86      0.40        71
#
#     accuracy                           0.81       935
#    macro avg       0.62      0.83      0.64       935
# weighted avg       0.93      0.81      0.85       935
#
# ROC-AUC = 0.912		AP = 0.614
# ----------------------------------------------------
# gac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.95      0.97       872
#         True       0.57      0.87      0.69        63
#
#     accuracy                           0.95       935
#    macro avg       0.78      0.91      0.83       935
# weighted avg       0.96      0.95      0.95       935
#
# ROC-AUC = 0.974		AP = 0.792
# ----------------------------------------------------
# gel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.97      0.96       873
#         True       0.40      0.32      0.36        62
#
#     accuracy                           0.92       935
#    macro avg       0.68      0.64      0.66       935
# weighted avg       0.92      0.92      0.92       935
#
# ROC-AUC = 0.785		AP = 0.343
# ----------------------------------------------------
# org
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.87      0.93       838
#         True       0.47      0.98      0.63        97
#
#     accuracy                           0.88       935
#    macro avg       0.73      0.92      0.78       935
# weighted avg       0.94      0.88      0.90       935
#
# ROC-AUC = 0.975		AP = 0.814
# ----------------------------------------------------
# pia
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.90      0.94       792
#         True       0.63      0.90      0.74       143
#
#     accuracy                           0.90       935
#    macro avg       0.80      0.90      0.84       935
# weighted avg       0.93      0.90      0.91       935
#
# ROC-AUC = 0.957		AP = 0.840
# ----------------------------------------------------
# sax
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.94      0.78      0.86       812
#         True       0.33      0.70      0.44       123
#
#     accuracy                           0.77       935
#    macro avg       0.64      0.74      0.65       935
# weighted avg       0.86      0.77      0.80       935
#
# ROC-AUC = 0.803		AP = 0.515
# ----------------------------------------------------
# tru
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.67      0.79       830
#         True       0.23      0.78      0.36       105
#
#     accuracy                           0.68       935
#    macro avg       0.60      0.73      0.57       935
# weighted avg       0.88      0.68      0.74       935
#
# ROC-AUC = 0.831		AP = 0.578
# ----------------------------------------------------
# vio
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.22      0.35       834
#         True       0.13      0.97      0.23       101
#
#     accuracy                           0.30       935
#    macro avg       0.56      0.59      0.29       935
# weighted avg       0.89      0.30      0.34       935
#
# ROC-AUC = 0.837		AP = 0.461
# ----------------------------------------------------
# voi
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99       925
#         True       0.32      0.70      0.44        10
#
#     accuracy                           0.98       935
#    macro avg       0.66      0.84      0.71       935
# weighted avg       0.99      0.98      0.98       935
#
# ROC-AUC = 0.981		AP = 0.729

# %% [markdown]
# # B -> B

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'B', 'B' 

globals()['models_' + train_set_name] = dict()

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_B
    Y_train_inst = Y_train_B_inst
    X_test_inst = X_test_B
    Y_test_inst = Y_test_B_inst

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]
    
    # store the classifier in the model dictionary
    globals()['models_' + train_set_name][instrument] = clf

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)

with open('models/models_' + train_set_name + '_' + embedding + debias_method + '.pickle', 'wb') as fdesc:
    pickle.dump(globals()['models_'+train_set_name], fdesc)
# Out:
# ----------------------------------------------------
# cel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.87      0.93       867
#         True       0.35      0.88      0.50        68
#
#     accuracy                           0.87       935
#    macro avg       0.67      0.88      0.71       935
# weighted avg       0.94      0.87      0.90       935
#
# ROC-AUC = 0.927		AP = 0.686
# ----------------------------------------------------
# cla
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.76      0.85       843
#         True       0.25      0.74      0.37        92
#
#     accuracy                           0.75       935
#    macro avg       0.61      0.75      0.61       935
# weighted avg       0.89      0.75      0.80       935
#
# ROC-AUC = 0.833		AP = 0.393
# ----------------------------------------------------
# flu
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.88      0.93       864
#         True       0.37      0.83      0.51        71
#
#     accuracy                           0.88       935
#    macro avg       0.68      0.86      0.72       935
# weighted avg       0.94      0.88      0.90       935
#
# ROC-AUC = 0.945		AP = 0.650
# ----------------------------------------------------
# gac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.96      0.98       872
#         True       0.64      0.86      0.73        63
#
#     accuracy                           0.96       935
#    macro avg       0.81      0.91      0.85       935
# weighted avg       0.97      0.96      0.96       935
#
# ROC-AUC = 0.978		AP = 0.841
# ----------------------------------------------------
# gel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.93      0.95       873
#         True       0.40      0.69      0.51        62
#
#     accuracy                           0.91       935
#    macro avg       0.69      0.81      0.73       935
# weighted avg       0.94      0.91      0.92       935
#
# ROC-AUC = 0.927		AP = 0.594
# ----------------------------------------------------
# org
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.92      0.96       838
#         True       0.58      0.98      0.73        97
#
#     accuracy                           0.92       935
#    macro avg       0.79      0.95      0.84       935
# weighted avg       0.95      0.92      0.93       935
#
# ROC-AUC = 0.988		AP = 0.899
# ----------------------------------------------------
# pia
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.93      0.96       792
#         True       0.72      0.93      0.81       143
#
#     accuracy                           0.93       935
#    macro avg       0.85      0.93      0.89       935
# weighted avg       0.95      0.93      0.94       935
#
# ROC-AUC = 0.978		AP = 0.922
# ----------------------------------------------------
# sax
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.83      0.89       812
#         True       0.40      0.77      0.53       123
#
#     accuracy                           0.82       935
#    macro avg       0.68      0.80      0.71       935
# weighted avg       0.89      0.82      0.84       935
#
# ROC-AUC = 0.878		AP = 0.646
# ----------------------------------------------------
# tru
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.86      0.91       830
#         True       0.43      0.81      0.56       105
#
#     accuracy                           0.86       935
#    macro avg       0.70      0.84      0.74       935
# weighted avg       0.91      0.86      0.87       935
#
# ROC-AUC = 0.921		AP = 0.756
# ----------------------------------------------------
# vio
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.20      0.34       834
#         True       0.13      0.97      0.23       101
#
#     accuracy                           0.29       935
#    macro avg       0.56      0.59      0.28       935
# weighted avg       0.89      0.29      0.32       935
#
# ROC-AUC = 0.849		AP = 0.558
# ----------------------------------------------------
# voi
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      1.00       925
#         True       0.62      0.80      0.70        10
#
#     accuracy                           0.99       935
#    macro avg       0.81      0.90      0.85       935
# weighted avg       0.99      0.99      0.99       935
#
# ROC-AUC = 0.994		AP = 0.819

# %% [markdown]
# # B -> A

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'B', 'A' 

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_B
    Y_train_inst = Y_train_B_inst
    X_test_inst = X_test_A
    Y_test_inst = Y_test_A_inst

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
# Out:
# ----------------------------------------------------
# cel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.97      0.97       728
#         True       0.18      0.17      0.17        30
#
#     accuracy                           0.94       758
#    macro avg       0.57      0.57      0.57       758
# weighted avg       0.93      0.94      0.94       758
#
# ROC-AUC = 0.731		AP = 0.123
# ----------------------------------------------------
# cla
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.94      0.96       723
#         True       0.32      0.54      0.40        35
#
#     accuracy                           0.93       758
#    macro avg       0.65      0.74      0.68       758
# weighted avg       0.95      0.93      0.93       758
#
# ROC-AUC = 0.761		AP = 0.319
# ----------------------------------------------------
# flu
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.90      0.93       714
#         True       0.28      0.66      0.39        44
#
#     accuracy                           0.88       758
#    macro avg       0.63      0.78      0.66       758
# weighted avg       0.94      0.88      0.90       758
#
# ROC-AUC = 0.846		AP = 0.548
# ----------------------------------------------------
# gac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.92      0.95       660
#         True       0.60      0.87      0.71        98
#
#     accuracy                           0.91       758
#    macro avg       0.79      0.89      0.83       758
# weighted avg       0.93      0.91      0.92       758
#
# ROC-AUC = 0.939		AP = 0.830
# ----------------------------------------------------
# gel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.88      0.66      0.76       628
#         True       0.25      0.55      0.35       130
#
#     accuracy                           0.65       758
#    macro avg       0.57      0.61      0.55       758
# weighted avg       0.77      0.65      0.69       758
#
# ROC-AUC = 0.650		AP = 0.223
# ----------------------------------------------------
# org
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.67      0.80       684
#         True       0.23      0.92      0.37        74
#
#     accuracy                           0.70       758
#    macro avg       0.61      0.80      0.59       758
# weighted avg       0.91      0.70      0.76       758
#
# ROC-AUC = 0.901		AP = 0.552
# ----------------------------------------------------
# pia
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.96      0.97       719
#         True       0.48      0.74      0.58        39
#
#     accuracy                           0.94       758
#    macro avg       0.73      0.85      0.78       758
# weighted avg       0.96      0.94      0.95       758
#
# ROC-AUC = 0.918		AP = 0.628
# ----------------------------------------------------
# sax
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.93      0.95       723
#         True       0.26      0.49      0.34        35
#
#     accuracy                           0.91       758
#    macro avg       0.62      0.71      0.64       758
# weighted avg       0.94      0.91      0.92       758
#
# ROC-AUC = 0.755		AP = 0.347
# ----------------------------------------------------
# tru
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.97      0.97       717
#         True       0.51      0.63      0.57        41
#
#     accuracy                           0.95       758
#    macro avg       0.74      0.80      0.77       758
# weighted avg       0.95      0.95      0.95       758
#
# ROC-AUC = 0.921		AP = 0.640
# ----------------------------------------------------
# vio
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.06      0.11       712
#         True       0.06      0.98      0.12        46
#
#     accuracy                           0.12       758
#    macro avg       0.52      0.52      0.12       758
# weighted avg       0.92      0.12      0.11       758
#
# ROC-AUC = 0.805		AP = 0.540
# ----------------------------------------------------
# voi
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.93      0.95      0.94       572
#         True       0.84      0.77      0.80       186
#
#     accuracy                           0.91       758
#    macro avg       0.88      0.86      0.87       758
# weighted avg       0.91      0.91      0.91       758
#
# ROC-AUC = 0.928		AP = 0.872

# %% [markdown]
# # save result

# %%
# save all result into a csv file
# result_all.to_csv('results/result_' + embedding + debias_method + '_trainboth.csv', index=False)
result_all.to_csv('results/result_' + embedding +  debias_method + '.csv', index=False)

# %%
# # save all result into a csv file
# debias_method = ''
# df_1 = pd.read_csv('results/result_' + 'vggish' + '.csv')
# df_2 = pd.read_csv('results/result_' + 'openl3' + '.csv')
# df_3 = pd.read_csv('results/result_' + 'yamnet' + '.csv')

# df = df_1.append(df_2).append(df_3)
# df.to_csv('results/result_' + '3embedding' + debias_method + '.csv', index=False)

# df = pd.read_csv('results/result_' + '3embedding' + debias_method + '.csv')

# sns.set_theme(context='notebook', style='whitegrid', palette='deep')

# sns.catplot(data=df, row='train_set', col='test_set', y='instrument', x='roc_auc', hue='embedding', kind='bar', 
#             height=4, aspect=1.2)
# plt.xlim([.4,1])
# plt.savefig('results/' + '3embedding' + debias_method + '_ori_sameratio.pdf')
