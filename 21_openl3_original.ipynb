# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import librosa
from tqdm import tqdm_notebook as tqdm
import json
import pandas as pd
import pickle
import os
import h5py
import collections as cl
from ast import literal_eval
import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, roc_auc_score, average_precision_score
from sklearn.preprocessing import StandardScaler
import random
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
param_grid = {'C': [10**k for k in range(-10, 6, 2)]}  
scoring = 'roc_auc'; cv = 3; random_state=42
random.seed(random_state)

# %%
with open("genre_map.json", "r") as f: # only consider 10 classes of Openmic dataset
    genre_map = json.load(f)
aligned_genre = list(genre_map)[:-1]

with open("instrument_map.json", "r") as f: # only consider 10 classes of Openmic dataset
    instrument_map = json.load(f)

# %%
# use a Pandas DataFrame to record all results and save into a csv file later
result_all = pd.DataFrame({'instrument': [],
                          'train_set': [],
                          'test_set': [],
                          'precision': [],
                          'recall': [],
                          'f1-score': [],
                          'support': [],
                          'accuracy': [],
                          'roc_auc': [],
                          'ap': [],
                          'embedding': [],
                         })

# %% [markdown]
# # Load embeddings and align classes

# %%
embedding = 'openl3'
debias_method = ''

# load embeddings
embeddings = h5py.File("embeddings.h5", "r")

# %%
###### IRMAS data ######
feature = np.array(embeddings["irmas"][embedding]["features"])
keys_ori = np.array(embeddings["irmas"][embedding]["keys"])
key_clip = np.unique(keys_ori)

feature_clip = []

for key in tqdm(key_clip):
    feature_clip.append(np.mean(feature[keys_ori[:]==key,:],axis=0))
    
feature_clip = np.array(feature_clip)
print(feature_clip.shape, key_clip.shape)
# Out:
#   0%|          | 0/6705 [00:00<?, ?it/s]
# (6705, 512) (6705,)

# %%
def load_feature(meta, feature_clip, key_clip):
    key_train = list(meta.loc[(meta['split'] == 'train')]['file_name'])
    key_test = list(meta.loc[(meta['split'] == 'test')]['file_name'])

    idx_train = [list(key_clip).index(item) for item in key_train]
    idx_test = [list(key_clip).index(item) for item in key_test]
   
    # cast the idx_* arrays to numpy structures
    idx_train = np.asarray(idx_train)
    idx_test = np.asarray(idx_test)

    # use the split indices to partition the features, labels, and masks
    X_train = feature_clip[idx_train,:]
    X_test = feature_clip[idx_test]

    Y_train = meta.loc[(meta['split'] == 'train')]['instrument'].values
    Y_test = meta.loc[(meta['split'] == 'test')]['instrument'].values

    genre_train = meta.loc[(meta['split'] == 'train')]['genre'].values
    genre_test = meta.loc[(meta['split'] == 'test')]['genre'].values

    return (X_train, Y_train), (X_test, Y_test), (genre_train, genre_test)

# %%
A_meta = pd.read_csv("A_meta.csv")
(X_train_A, Y_train_A), (X_test_A, Y_test_A), (genre_train_A, genre_test_A) = load_feature(A_meta, feature_clip, key_clip)
B_meta = pd.read_csv("B_meta.csv")
(X_train_B, Y_train_B), (X_test_B, Y_test_B), (genre_train_B, genre_test_B) = load_feature(B_meta, feature_clip, key_clip)

# %% [markdown]
# # A -> A

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'A', 'A' 

globals()['models_' + train_set_name] = dict()

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_A
    Y_train_inst = Y_train_A_inst
    X_test_inst = X_test_A
    Y_test_inst = Y_test_A_inst

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]
    
    # store the classifier in the model dictionary
    globals()['models_' + train_set_name][instrument] = clf

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)

with open('models/models_' + train_set_name + '_' + embedding + debias_method + '.pickle', 'wb') as fdesc:
    pickle.dump(globals()['models_'+train_set_name], fdesc)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.99      0.99       728
#         True       0.78      0.70      0.74        30
#
#     accuracy                           0.98       758
#    macro avg       0.88      0.85      0.86       758
# weighted avg       0.98      0.98      0.98       758
#
# ROC-AUC = 0.958		AP = 0.803
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.99      0.99       723
#         True       0.80      0.80      0.80        35
#
#     accuracy                           0.98       758
#    macro avg       0.90      0.90      0.90       758
# weighted avg       0.98      0.98      0.98       758
#
# ROC-AUC = 0.983		AP = 0.872
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.98      0.98       714
#         True       0.74      0.73      0.74        44
#
#     accuracy                           0.97       758
#    macro avg       0.86      0.86      0.86       758
# weighted avg       0.97      0.97      0.97       758
#
# ROC-AUC = 0.963		AP = 0.762
# ----------------------------------------------------
# guitar-ac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       660
#         True       0.83      0.93      0.88        98
#
#     accuracy                           0.97       758
#    macro avg       0.91      0.95      0.93       758
# weighted avg       0.97      0.97      0.97       758
#
# ROC-AUC = 0.992		AP = 0.938
# ----------------------------------------------------
# guitar-el
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.93      0.95       628
#         True       0.72      0.91      0.81       130
#
#     accuracy                           0.92       758
#    macro avg       0.85      0.92      0.88       758
# weighted avg       0.94      0.92      0.93       758
#
# ROC-AUC = 0.974		AP = 0.896
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.98      0.99       684
#         True       0.84      0.95      0.89        74
#
#     accuracy                           0.98       758
#    macro avg       0.92      0.96      0.94       758
# weighted avg       0.98      0.98      0.98       758
#
# ROC-AUC = 0.994		AP = 0.941
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.98      0.99       719
#         True       0.74      0.79      0.77        39
#
#     accuracy                           0.97       758
#    macro avg       0.86      0.89      0.88       758
# weighted avg       0.98      0.97      0.98       758
#
# ROC-AUC = 0.989		AP = 0.839
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.98      0.98       723
#         True       0.56      0.57      0.56        35
#
#     accuracy                           0.96       758
#    macro avg       0.77      0.77      0.77       758
# weighted avg       0.96      0.96      0.96       758
#
# ROC-AUC = 0.882		AP = 0.554
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.99      0.99       717
#         True       0.80      0.80      0.80        41
#
#     accuracy                           0.98       758
#    macro avg       0.90      0.90      0.90       758
# weighted avg       0.98      0.98      0.98       758
#
# ROC-AUC = 0.968		AP = 0.833
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.96      0.97       712
#         True       0.56      0.76      0.64        46
#
#     accuracy                           0.95       758
#    macro avg       0.77      0.86      0.81       758
# weighted avg       0.96      0.95      0.95       758
#
# ROC-AUC = 0.958		AP = 0.652
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.98      0.98       572
#         True       0.93      0.95      0.94       186
#
#     accuracy                           0.97       758
#    macro avg       0.95      0.96      0.96       758
# weighted avg       0.97      0.97      0.97       758
#
# ROC-AUC = 0.991		AP = 0.982

# %% [markdown]
# # A -> B

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'A', 'B' 

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_A
    Y_train_inst = Y_train_A_inst
    X_test_inst = X_test_B
    Y_test_inst = Y_test_B_inst

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.96      0.96       867
#         True       0.44      0.41      0.43        68
#
#     accuracy                           0.92       935
#    macro avg       0.70      0.69      0.69       935
# weighted avg       0.92      0.92      0.92       935
#
# ROC-AUC = 0.904		AP = 0.517
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.93      0.94      0.93       843
#         True       0.38      0.35      0.36        92
#
#     accuracy                           0.88       935
#    macro avg       0.66      0.64      0.65       935
# weighted avg       0.88      0.88      0.88       935
#
# ROC-AUC = 0.794		AP = 0.333
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.94      0.92      0.93       864
#         True       0.24      0.31      0.27        71
#
#     accuracy                           0.87       935
#    macro avg       0.59      0.62      0.60       935
# weighted avg       0.89      0.87      0.88       935
#
# ROC-AUC = 0.814		AP = 0.300
# ----------------------------------------------------
# guitar-ac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       872
#         True       0.66      0.86      0.74        63
#
#     accuracy                           0.96       935
#    macro avg       0.82      0.91      0.86       935
# weighted avg       0.97      0.96      0.96       935
#
# ROC-AUC = 0.976		AP = 0.817
# ----------------------------------------------------
# guitar-el
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.95      0.96       873
#         True       0.39      0.45      0.42        62
#
#     accuracy                           0.92       935
#    macro avg       0.67      0.70      0.69       935
# weighted avg       0.92      0.92      0.92       935
#
# ROC-AUC = 0.805		AP = 0.445
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.95      0.96       838
#         True       0.64      0.77      0.70        97
#
#     accuracy                           0.93       935
#    macro avg       0.81      0.86      0.83       935
# weighted avg       0.94      0.93      0.93       935
#
# ROC-AUC = 0.969		AP = 0.808
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.96      0.97       792
#         True       0.81      0.90      0.85       143
#
#     accuracy                           0.95       935
#    macro avg       0.90      0.93      0.91       935
# weighted avg       0.96      0.95      0.95       935
#
# ROC-AUC = 0.983		AP = 0.924
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.88      0.97      0.92       812
#         True       0.40      0.14      0.20       123
#
#     accuracy                           0.86       935
#    macro avg       0.64      0.55      0.56       935
# weighted avg       0.82      0.86      0.83       935
#
# ROC-AUC = 0.720		AP = 0.298
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.92      0.96      0.94       830
#         True       0.53      0.38      0.44       105
#
#     accuracy                           0.89       935
#    macro avg       0.73      0.67      0.69       935
# weighted avg       0.88      0.89      0.88       935
#
# ROC-AUC = 0.836		AP = 0.475
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.81      0.88       834
#         True       0.30      0.67      0.42       101
#
#     accuracy                           0.80       935
#    macro avg       0.63      0.74      0.65       935
# weighted avg       0.88      0.80      0.83       935
#
# ROC-AUC = 0.843		AP = 0.403
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       925
#         True       0.60      0.60      0.60        10
#
#     accuracy                           0.99       935
#    macro avg       0.80      0.80      0.80       935
# weighted avg       0.99      0.99      0.99       935
#
# ROC-AUC = 0.987		AP = 0.714

# %% [markdown]
# # B -> B

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'B', 'B' 

globals()['models_' + train_set_name] = dict()

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_B
    Y_train_inst = Y_train_B_inst
    X_test_inst = X_test_B
    Y_test_inst = Y_test_B_inst

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]
    
    # store the classifier in the model dictionary
    globals()['models_' + train_set_name][instrument] = clf

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)

with open('models/models_' + train_set_name + '_' + embedding + debias_method + '.pickle', 'wb') as fdesc:
    pickle.dump(globals()['models_'+train_set_name], fdesc)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.99      0.99       867
#         True       0.84      0.93      0.88        68
#
#     accuracy                           0.98       935
#    macro avg       0.92      0.96      0.94       935
# weighted avg       0.98      0.98      0.98       935
#
# ROC-AUC = 0.994		AP = 0.942
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.95      0.97       843
#         True       0.65      0.85      0.74        92
#
#     accuracy                           0.94       935
#    macro avg       0.82      0.90      0.85       935
# weighted avg       0.95      0.94      0.94       935
#
# ROC-AUC = 0.966		AP = 0.833
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.97      0.97       864
#         True       0.66      0.79      0.72        71
#
#     accuracy                           0.95       935
#    macro avg       0.82      0.88      0.85       935
# weighted avg       0.96      0.95      0.95       935
#
# ROC-AUC = 0.967		AP = 0.825
# ----------------------------------------------------
# guitar-ac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99       872
#         True       0.80      0.97      0.88        63
#
#     accuracy                           0.98       935
#    macro avg       0.90      0.98      0.93       935
# weighted avg       0.98      0.98      0.98       935
#
# ROC-AUC = 0.997		AP = 0.959
# ----------------------------------------------------
# guitar-el
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.98      0.99       873
#         True       0.75      0.87      0.81        62
#
#     accuracy                           0.97       935
#    macro avg       0.87      0.93      0.90       935
# weighted avg       0.97      0.97      0.97       935
#
# ROC-AUC = 0.985		AP = 0.867
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.95      0.97       838
#         True       0.67      0.97      0.79        97
#
#     accuracy                           0.95       935
#    macro avg       0.83      0.96      0.88       935
# weighted avg       0.96      0.95      0.95       935
#
# ROC-AUC = 0.992		AP = 0.937
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.99      0.99       792
#         True       0.95      0.94      0.95       143
#
#     accuracy                           0.98       935
#    macro avg       0.97      0.97      0.97       935
# weighted avg       0.98      0.98      0.98       935
#
# ROC-AUC = 0.996		AP = 0.986
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.91      0.93       812
#         True       0.56      0.79      0.65       123
#
#     accuracy                           0.89       935
#    macro avg       0.76      0.85      0.79       935
# weighted avg       0.91      0.89      0.90       935
#
# ROC-AUC = 0.925		AP = 0.704
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.96      0.97       830
#         True       0.75      0.87      0.81       105
#
#     accuracy                           0.95       935
#    macro avg       0.87      0.92      0.89       935
# weighted avg       0.96      0.95      0.95       935
#
# ROC-AUC = 0.969		AP = 0.887
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.93      0.95       834
#         True       0.56      0.78      0.65       101
#
#     accuracy                           0.91       935
#    macro avg       0.77      0.85      0.80       935
# weighted avg       0.93      0.91      0.92       935
#
# ROC-AUC = 0.947		AP = 0.756
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       925
#         True       1.00      0.60      0.75        10
#
#     accuracy                           1.00       935
#    macro avg       1.00      0.80      0.87       935
# weighted avg       1.00      1.00      1.00       935
#
# ROC-AUC = 0.999		AP = 0.956

# %% [markdown]
# # B -> A

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'B', 'A' 

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_B
    Y_train_inst = Y_train_B_inst
    X_test_inst = X_test_A
    Y_test_inst = Y_test_A_inst

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.97      0.97       728
#         True       0.29      0.30      0.30        30
#
#     accuracy                           0.94       758
#    macro avg       0.63      0.63      0.63       758
# weighted avg       0.94      0.94      0.94       758
#
# ROC-AUC = 0.889		AP = 0.335
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.92      0.95       723
#         True       0.25      0.54      0.34        35
#
#     accuracy                           0.90       758
#    macro avg       0.61      0.73      0.64       758
# weighted avg       0.94      0.90      0.92       758
#
# ROC-AUC = 0.833		AP = 0.260
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.95      0.95       714
#         True       0.27      0.32      0.29        44
#
#     accuracy                           0.91       758
#    macro avg       0.61      0.63      0.62       758
# weighted avg       0.92      0.91      0.91       758
#
# ROC-AUC = 0.776		AP = 0.265
# ----------------------------------------------------
# guitar-ac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.97      0.97       660
#         True       0.79      0.85      0.82        98
#
#     accuracy                           0.95       758
#    macro avg       0.88      0.91      0.89       758
# weighted avg       0.95      0.95      0.95       758
#
# ROC-AUC = 0.969		AP = 0.863
# ----------------------------------------------------
# guitar-el
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.91      0.93      0.92       628
#         True       0.63      0.56      0.59       130
#
#     accuracy                           0.87       758
#    macro avg       0.77      0.75      0.76       758
# weighted avg       0.86      0.87      0.87       758
#
# ROC-AUC = 0.852		AP = 0.635
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.79      0.87       684
#         True       0.29      0.80      0.43        74
#
#     accuracy                           0.79       758
#    macro avg       0.63      0.79      0.65       758
# weighted avg       0.91      0.79      0.83       758
#
# ROC-AUC = 0.890		AP = 0.569
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.99      0.98       719
#         True       0.67      0.46      0.55        39
#
#     accuracy                           0.96       758
#    macro avg       0.82      0.72      0.76       758
# weighted avg       0.96      0.96      0.96       758
#
# ROC-AUC = 0.959		AP = 0.678
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.81      0.88       723
#         True       0.09      0.37      0.14        35
#
#     accuracy                           0.79       758
#    macro avg       0.53      0.59      0.51       758
# weighted avg       0.92      0.79      0.85       758
#
# ROC-AUC = 0.728		AP = 0.090
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.97      0.97       717
#         True       0.44      0.46      0.45        41
#
#     accuracy                           0.94       758
#    macro avg       0.71      0.71      0.71       758
# weighted avg       0.94      0.94      0.94       758
#
# ROC-AUC = 0.868		AP = 0.535
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.88      0.93       712
#         True       0.24      0.57      0.34        46
#
#     accuracy                           0.87       758
#    macro avg       0.60      0.73      0.63       758
# weighted avg       0.93      0.87      0.89       758
#
# ROC-AUC = 0.834		AP = 0.334
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.91      0.98      0.95       572
#         True       0.94      0.72      0.81       186
#
#     accuracy                           0.92       758
#    macro avg       0.93      0.85      0.88       758
# weighted avg       0.92      0.92      0.91       758
#
# ROC-AUC = 0.965		AP = 0.929

# %% [markdown]
# # save result

# %%
# save all result into a csv file
# result_all.to_csv('results/result_' + embedding + debias_method + '_trainboth.csv', index=False)
result_all.to_csv('results/result_' + embedding +  debias_method + '.csv', index=False)

# %%
# # save all result into a csv file
# debias_method = ''
# df_1 = pd.read_csv('results/result_' + 'vggish' + '.csv')
# df_2 = pd.read_csv('results/result_' + 'openl3' + '.csv')
# df_3 = pd.read_csv('results/result_' + 'yamnet' + '.csv')

# df = df_1.append(df_2).append(df_3)
# df.to_csv('results/result_' + '3embedding' + debias_method + '.csv', index=False)

# df = pd.read_csv('results/result_' + '3embedding' + debias_method + '.csv')

# sns.set_theme(context='notebook', style='whitegrid', palette='deep')

# sns.catplot(data=df, row='train_set', col='test_set', y='instrument', x='roc_auc', hue='embedding', kind='bar', 
#             height=4, aspect=1.2)
# plt.xlim([.4,1])
# plt.savefig('results/' + '3embedding' + debias_method + '_ori_sameratio.pdf')
