# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tqdm import tqdm_notebook as tqdm
import json
import pandas as pd
import os
import h5py
from ast import literal_eval
import re
import pickle
import numpy.linalg as la
import collections
import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, roc_auc_score, average_precision_score
from sklearn import svm
from sklearn.kernel_approximation import RBFSampler
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn_extra.kernel_approximation import Fastfood
from sklearn.metrics import pairwise_distances

# %%
param_grid = {'C': [10**k for k in range(-10, 4, 1)]}  
scoring = 'roc_auc'; cv = 3

# %% [markdown]
# # Load embeddings and align classes

# %%
embedding = 'yamnet'
debias_method = '-klda-genre'

# %%
# load embeddings
embeddings = h5py.File('embeddings.h5', 'r')

def printname(name):
    print(name)
embeddings.visit(printname)
# Out:
# irmas
# irmas/openl3
# irmas/openl3/features
# irmas/openl3/keys
# irmas/vggish
# irmas/vggish/features
# irmas/vggish/keys
# irmas/yamnet
# irmas/yamnet/features
# irmas/yamnet/keys
# openmic
# openmic/openl3
# openmic/openl3/features
# openmic/openl3/keys
# openmic/vggish
# openmic/vggish/features
# openmic/vggish/keys
# openmic/yamnet
# openmic/yamnet/features
# openmic/yamnet/keys

# %%
with open('class-map-10.json', 'r') as f: # only consider 10 classes of Openmic dataset
    class_map = json.load(f)
    
class_map
# Out:
# {'cello': 3,
#  'clarinet': 4,
#  'flute': 7,
#  'guitar': 8,
#  'organ': 11,
#  'piano': 12,
#  'saxophone': 13,
#  'trumpet': 16,
#  'violin': 18,
#  'voice': 19}

# %%
# use a dict to align the classes between Openmic dataset (key) and Irmas dataset (val)
class_align = {'cello': 'cel',
               'clarinet': 'cla',
               'flute': 'flu',
               'guitar': ['gac', 'gel'],
               'organ': 'org',
               'piano': 'pia',
               'saxophone': 'sax',
               'trumpet': 'tru',
               'violin': 'vio',
               'voice': 'voi'}

# %%
# use a Pandas DataFrame to record all results and save into a csv file later
result_all = pd.DataFrame({'instrument': [],
                          'train_set': [],
                          'test_set': [],
                          'precision': [],
                          'recall': [],
                          'f1-score': [],
                          'support': [],
                          'accuracy': [],
                          'roc_auc': [],
                          'ap': [],
                          'embedding': [],
                         })

# %% [markdown]
# # irmas->irmas

# %%
# irmas: Vggish embedding
feature = np.array(embeddings['irmas'][embedding]['features'])
keys_ori = np.array(embeddings['irmas'][embedding]['keys'])
print(feature.shape, keys_ori.shape)

key_clip = np.unique(keys_ori)
print(key_clip.shape)

feature_clip = []

for key in tqdm(key_clip):
    feature_clip.append(np.mean(feature[keys_ori[:]==key,:],axis=0))
    
feature_clip = np.array(feature_clip)
key_clip = np.array([str(k, 'utf-8') for k in key_clip])
print(feature_clip.shape, key_clip.shape)
# Out:
# (33525, 1024) (33525,)
# (6705,)
#   0%|          | 0/6705 [00:00<?, ?it/s]
# (6705, 1024) (6705,)

# %%
key_train = set(pd.read_csv('irmas_train.csv', header=None, squeeze=True))
key_test = set(pd.read_csv('irmas_test.csv', header=None, squeeze=True))

# %%
# these loops go through all sample keys, and save their row numbers to either idx_train or idx_test
idx_train, idx_test = [], []

for k in range(len(key_clip)):
    if str(key_clip[k]) in key_train:
        idx_train.append(k)
    elif str(key_clip[k]) in key_test:
        idx_test.append(k)
    else:
        # This should never happen, but better safe than sorry.
        raise RuntimeError('Unknown sample key={}! Abort!'.format(str(key_clip[k])))
        
# cast the idx_* arrays to numpy structures
idx_train = np.asarray(idx_train)
idx_test = np.asarray(idx_test)

# %%
#keys = np.array([str(k, encoding='utf-8') for k in key_clip])
keys = np.array(key_clip)
keys = [key[key.index('[')+1:key.index(']')] for key in keys]

for key in class_align:
    keys = [key if x in class_align[key] else x for x in keys]
    
keys = np.array(keys)
np.unique(keys)
# Out:
# array(['cello', 'clarinet', 'flute', 'guitar', 'organ', 'piano',
#        'saxophone', 'trumpet', 'violin', 'voice'], dtype='<U9')

# %%
# use the split indices to partition the features, labels, and masks
X_train_irmas = feature_clip[idx_train,:]
X_test_irmas = feature_clip[idx_test]

Y_true_train_irmas = keys[idx_train]
Y_true_test_irmas = keys[idx_test]

X_train = X_train_irmas
X_test = X_test_irmas

Y_true_train = Y_true_train_irmas
Y_true_test = Y_true_test_irmas

# %%
# standardize embedding
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# kernelize embedding with fastfood
Sampler = Fastfood(n_components=4*X_train.shape[1], random_state=0,
                                sigma=np.median(pairwise_distances(X_train, metric='l2')))
X_train = Sampler.fit_transform(X_train)
X_test = Sampler.transform(X_test)

############################# project the LDA direction #############################
file = open('models/datasep_' + embedding + debias_method + '.pickle', 'rb')
globals()['LDAcoef_' + embedding] = pickle.load(file)
file.close()

W = globals()['LDAcoef_' + embedding].copy()
U, s, V = la.svd(W, full_matrices=False)
A = np.dot(V.T, V)
print(W.shape, U.shape, s.shape, V.shape, A.shape)

Xdeb_train = X_train.dot(np.eye(len(A)) - A)
Xdeb_test = X_test.dot(np.eye(len(A)) - A)
print(Xdeb_train.shape, Xdeb_test.shape)

X_train = Xdeb_train; X_test = Xdeb_test; del(Xdeb_train, Xdeb_test)
print(X_train.shape, X_test.shape)
# Out:
# (5, 8192) (5, 5) (5,) (5, 8192) (8192, 8192)
# (5039, 8192) (1666, 8192)
# (5039, 8192) (1666, 8192)

# %%
train_set_name, test_set_name = 'irmas', 'irmas'

# use a dictionary to include the classifier for each instrument trained on the dataset based on the embedding
globals()['models_'+train_set_name] = dict()  

# iterate over all istrument classes, and fit a model for each one
for instrument in class_align:
    
    # get the training and testing labels for each instrument
    Y_true_train_inst = Y_true_train==instrument
    Y_true_test_inst = Y_true_test==instrument
    
    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=0, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)  
    
    # fit the model
    clf.fit(X_train, Y_true_train_inst)
    
    # predict
    Y_pred_test_inst = clf.predict(X_test)
    
    # Get prediction scores for the positive class
    Y_pred_test_scores = clf.predict_proba(X_test)[:, 1]
    
    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_true_test_inst, Y_pred_test_inst))
    
    model_auc = roc_auc_score(Y_true_test_inst, Y_pred_test_scores)
    model_ap = average_precision_score(Y_true_test_inst, Y_pred_test_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # store the classifier in the model dictionary
    globals()['models_'+train_set_name][instrument] = clf
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_true_test_inst, Y_pred_test_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    
    report_accuracy = pd.DataFrame(classification_report(Y_true_test_inst, Y_pred_test_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
    
with open('models/models_' + train_set_name + '_' + embedding + debias_method + '.pickle', 'wb') as fdesc:
    pickle.dump(globals()['models_'+train_set_name], fdesc)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.94      0.96      1572
#         True       0.46      0.84      0.59        94
#
#     accuracy                           0.93      1666
#    macro avg       0.72      0.89      0.78      1666
# weighted avg       0.96      0.93      0.94      1666
#
# ROC-AUC = 0.957		AP = 0.758
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.91      0.94      1539
#         True       0.43      0.83      0.56       127
#
#     accuracy                           0.90      1666
#    macro avg       0.71      0.87      0.75      1666
# weighted avg       0.94      0.90      0.92      1666
#
# ROC-AUC = 0.915		AP = 0.682
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.95      0.96      1545
#         True       0.52      0.69      0.59       121
#
#     accuracy                           0.93      1666
#    macro avg       0.75      0.82      0.78      1666
# weighted avg       0.94      0.93      0.93      1666
#
# ROC-AUC = 0.926		AP = 0.685
# ----------------------------------------------------
# guitar
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.92      0.94      1320
#         True       0.75      0.86      0.80       346
#
#     accuracy                           0.91      1666
#    macro avg       0.86      0.89      0.87      1666
# weighted avg       0.92      0.91      0.91      1666
#
# ROC-AUC = 0.967		AP = 0.898
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.94      0.96      1492
#         True       0.64      0.95      0.76       174
#
#     accuracy                           0.94      1666
#    macro avg       0.82      0.94      0.86      1666
# weighted avg       0.96      0.94      0.94      1666
#
# ROC-AUC = 0.987		AP = 0.888
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.98      0.98      1496
#         True       0.84      0.82      0.83       170
#
#     accuracy                           0.97      1666
#    macro avg       0.91      0.90      0.91      1666
# weighted avg       0.97      0.97      0.97      1666
#
# ROC-AUC = 0.969		AP = 0.870
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.85      0.91      1516
#         True       0.34      0.79      0.48       150
#
#     accuracy                           0.85      1666
#    macro avg       0.66      0.82      0.69      1666
# weighted avg       0.92      0.85      0.87      1666
#
# ROC-AUC = 0.906		AP = 0.577
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.95      0.96      1516
#         True       0.61      0.83      0.70       150
#
#     accuracy                           0.94      1666
#    macro avg       0.80      0.89      0.83      1666
# weighted avg       0.95      0.94      0.94      1666
#
# ROC-AUC = 0.962		AP = 0.858
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.92      0.95      1523
#         True       0.46      0.74      0.57       143
#
#     accuracy                           0.90      1666
#    macro avg       0.72      0.83      0.76      1666
# weighted avg       0.93      0.90      0.91      1666
#
# ROC-AUC = 0.906		AP = 0.686
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98      1475
#         True       0.83      0.95      0.89       191
#
#     accuracy                           0.97      1666
#    macro avg       0.91      0.96      0.93      1666
# weighted avg       0.97      0.97      0.97      1666
#
# ROC-AUC = 0.993		AP = 0.938

# %% [markdown]
# # openmic->openmic

# %%
feature = np.array(embeddings['openmic'][embedding]['features'])
keys = np.array(embeddings['openmic'][embedding]['keys'])
print(feature.shape, keys.shape)

key_clip = np.unique(keys)

feature_clip = []

for key in tqdm(key_clip):
    feature_clip.append(np.mean(feature[keys[:]==key,:],axis=0))
    
feature_clip = np.array(feature_clip)
print(feature_clip.shape, key_clip.shape)

key_clip = np.array([str(k, 'utf-8') for k in key_clip])
# Out:
# (380000, 1024) (380000,)
#   0%|          | 0/20000 [00:00<?, ?it/s]
# (20000, 1024) (20000,)

# %%
# key-label map using the information from the dataset source
data_root = 'openmic-2018/'

np_load_old = np.load   # save np.load
np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True,**k)   # modify the default parameters of np.load

Ytrue = np.load(os.path.join(data_root, 'openmic-2018.npz'))['Y_true']
Ymask = np.load(os.path.join(data_root, 'openmic-2018.npz'))['Y_mask']
sample_key = np.load(os.path.join(data_root, 'openmic-2018.npz'))['sample_key']

np.load = np_load_old   # restore np.load for future normal usage
del(np_load_old)

print(Ytrue.shape, Ymask.shape, sample_key.shape)
# Out:
# (20000, 20) (20000, 20) (20000,)

# %%
Y_true = []
Y_mask = []

for key in tqdm(key_clip):
    Y_true.append(Ytrue[sample_key==key])
    Y_mask.append(Ymask[sample_key==key])
    
Y_true = np.squeeze(np.array(Y_true))
Y_mask = np.squeeze(np.array(Y_mask))

print(feature_clip.shape, Y_true.shape, Y_mask.shape)
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
# (20000, 1024) (20000, 20) (20000, 20)

# %%
# train-test split
train_set = set(pd.read_csv(data_root + 'openmic2018_train.csv', header=None, squeeze=True))
test_set = set(pd.read_csv(data_root + 'openmic2018_test.csv', header=None, squeeze=True))
print('# Train: {},  # Test: {}'.format(len(train_set), len(test_set)))
# Out:
# # Train: 14915,  # Test: 5085

# %%
idx_train, idx_test = [], []

for idx, n in enumerate(key_clip):
    if n in train_set:
        idx_train.append(idx)
    elif n in test_set:
        idx_test.append(idx)
    else:
        raise RuntimeError('Unknown sample key={}! Abort!'.format(key_clip[n]))
        
idx_train = np.asarray(idx_train)
idx_test = np.asarray(idx_test)

# %%
X_train_openmic = feature_clip[idx_train]
X_test_openmic = feature_clip[idx_test]

Y_true_train_openmic = Y_true[idx_train]
Y_true_test_openmic = Y_true[idx_test]

Y_mask_train = Y_mask[idx_train]
Y_mask_test = Y_mask[idx_test]

X_train = X_train_openmic
X_test = X_test_openmic

Y_true_train = Y_true_train_openmic
Y_true_test = Y_true_test_openmic

# %%
# standardize embedding
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# kernelize embedding with fastfood
Sampler = Fastfood(n_components=4*X_train.shape[1], random_state=0,
                                sigma=np.median(pairwise_distances(X_train, metric='l2')))
X_train = Sampler.fit_transform(X_train)
X_test = Sampler.transform(X_test)

Xdeb_train = X_train.dot(np.eye(len(A)) - A)
Xdeb_test = X_test.dot(np.eye(len(A)) - A)
print(Xdeb_train.shape, Xdeb_test.shape)

X_train = Xdeb_train; X_test = Xdeb_test; del(Xdeb_train, Xdeb_test)
print(X_train.shape, X_test.shape)
# Out:
# (14915, 8192) (5085, 8192)
# (14915, 8192) (5085, 8192)

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'openmic', 'openmic'

# use a dictionary to include the classifier for each instrument trained on the dataset based on the embedding
globals()['models_'+train_set_name] = dict()  

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in class_align:
    
    # Map the instrument name to its column number
    inst_num = class_map[instrument]
    
    # First, sub-sample the data: we need to select down to the data for which we have annotations
    # This is what the mask arrays are for
    train_inst = Y_mask_train[:, inst_num]
    test_inst = Y_mask_test[:, inst_num]
    
    # Here, we're using the Y_mask_train array to slice out only the training examples
    # for which we have annotations for the given class
    X_train_inst = X_train[train_inst]
    
    # Again, we slice the labels to the annotated examples
    # We thresold the label likelihoods at 0.5 to get binary labels
    Y_true_train_inst = Y_true_train[train_inst, inst_num] >= 0.5
    
    # Repeat the above slicing and dicing but for the test set
    X_test_inst = X_test[test_inst]
    Y_true_test_inst = Y_true_test[test_inst, inst_num] >= 0.5

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=0, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_true_train_inst)

    # predict
    Y_pred_test_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_test_scores = clf.predict_proba(X_test_inst)[:, 1]
    
    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_true_test_inst, Y_pred_test_inst))
    
    model_auc = roc_auc_score(Y_true_test_inst, Y_pred_test_scores)
    model_ap = average_precision_score(Y_true_test_inst, Y_pred_test_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # store the classifier in the model dictionary
    globals()['models_'+train_set_name][instrument] = clf
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_true_test_inst, Y_pred_test_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    
    report_accuracy = pd.DataFrame(classification_report(Y_true_test_inst, Y_pred_test_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
    
with open('models/models_' + train_set_name + '_' + embedding + debias_method + '.pickle', 'wb') as fdesc:
    pickle.dump(globals()['models_'+train_set_name], fdesc)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.82      0.82      0.82       259
#         True       0.80      0.80      0.80       226
#
#     accuracy                           0.81       485
#    macro avg       0.81      0.81      0.81       485
# weighted avg       0.81      0.81      0.81       485
#
# ROC-AUC = 0.907		AP = 0.880
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.89      0.60      0.72       503
#         True       0.33      0.73      0.46       137
#
#     accuracy                           0.63       640
#    macro avg       0.61      0.67      0.59       640
# weighted avg       0.77      0.63      0.66       640
#
# ROC-AUC = 0.756		AP = 0.468
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.85      0.65      0.74       387
#         True       0.49      0.74      0.59       175
#
#     accuracy                           0.68       562
#    macro avg       0.67      0.70      0.67       562
# weighted avg       0.74      0.68      0.69       562
#
# ROC-AUC = 0.804		AP = 0.693
# ----------------------------------------------------
# guitar
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.90      0.99      0.94       150
#         True       0.99      0.94      0.97       286
#
#     accuracy                           0.96       436
#    macro avg       0.95      0.97      0.96       436
# weighted avg       0.96      0.96      0.96       436
#
# ROC-AUC = 0.991		AP = 0.996
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.84      0.81      0.82       310
#         True       0.55      0.60      0.57       121
#
#     accuracy                           0.75       431
#    macro avg       0.69      0.70      0.70       431
# weighted avg       0.76      0.75      0.75       431
#
# ROC-AUC = 0.829		AP = 0.632
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.91      0.89      0.90       130
#         True       0.95      0.96      0.96       285
#
#     accuracy                           0.94       415
#    macro avg       0.93      0.93      0.93       415
# weighted avg       0.94      0.94      0.94       415
#
# ROC-AUC = 0.984		AP = 0.992
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.87      0.83      0.85       324
#         True       0.83      0.87      0.85       305
#
#     accuracy                           0.85       629
#    macro avg       0.85      0.85      0.85       629
# weighted avg       0.85      0.85      0.85       629
#
# ROC-AUC = 0.922		AP = 0.917
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.84      0.81      0.82       467
#         True       0.73      0.77      0.75       318
#
#     accuracy                           0.79       785
#    macro avg       0.78      0.79      0.78       785
# weighted avg       0.79      0.79      0.79       785
#
# ROC-AUC = 0.879		AP = 0.841
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.80      0.84      0.82       237
#         True       0.90      0.87      0.89       394
#
#     accuracy                           0.86       631
#    macro avg       0.85      0.85      0.85       631
# weighted avg       0.86      0.86      0.86       631
#
# ROC-AUC = 0.938		AP = 0.957
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.88      0.92      0.90       150
#         True       0.94      0.92      0.93       224
#
#     accuracy                           0.92       374
#    macro avg       0.91      0.92      0.92       374
# weighted avg       0.92      0.92      0.92       374
#
# ROC-AUC = 0.977		AP = 0.986

# %% [markdown]
# # irmas->openmic

# %%
X_train = X_train_irmas
X_test = X_test_openmic

Y_true_train = Y_true_train_irmas
Y_true_test = Y_true_test_openmic

# standardize embedding
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# kernelize embedding with fastfood
Sampler = Fastfood(n_components=4*X_train.shape[1], random_state=0,
                                sigma=np.median(pairwise_distances(X_train, metric='l2')))
X_train = Sampler.fit_transform(X_train)
X_test = Sampler.transform(X_test)

Xdeb_train = X_train.dot(np.eye(len(A)) - A)
Xdeb_test = X_test.dot(np.eye(len(A)) - A)
print(Xdeb_train.shape, Xdeb_test.shape)

X_train = Xdeb_train; X_test = Xdeb_test; del(Xdeb_train, Xdeb_test)
print(X_train.shape, X_test.shape)
# Out:
# (5039, 8192) (5085, 8192)
# (5039, 8192) (5085, 8192)

# %%
train_set_name, test_set_name = 'irmas', 'openmic' 

# iterate over all istrument classes, and fit a model for each one
for instrument in class_align:
    
    # Map the instrument name to its column number
    inst_num = class_map[instrument]
    
    # First, sub-sample the data: we need to select down to the data for which we have annotations 
    # This is what the mask arrays are for
    test_inst = Y_mask_test[:, inst_num]

    # Repeat the above slicing and dicing but for the test set
    X_test_inst = X_test[test_inst]
    Y_true_test_inst = Y_true_test[test_inst, inst_num] >= 0.5

    # evaluate the classifier 
    Y_pred_test_inst =  globals()['models_'+train_set_name][instrument].predict(X_test_inst)
    Y_pred_test_scores =  globals()['models_'+train_set_name][instrument].predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_true_test_inst, Y_pred_test_inst))
    
    model_auc = roc_auc_score(Y_true_test_inst, Y_pred_test_scores)
    model_ap = average_precision_score(Y_true_test_inst, Y_pred_test_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_true_test_inst, Y_pred_test_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    
    report_accuracy = pd.DataFrame(classification_report(Y_true_test_inst, Y_pred_test_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.67      0.83      0.74       259
#         True       0.73      0.53      0.61       226
#
#     accuracy                           0.69       485
#    macro avg       0.70      0.68      0.67       485
# weighted avg       0.69      0.69      0.68       485
#
# ROC-AUC = 0.784		AP = 0.755
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.83      0.81      0.82       503
#         True       0.37      0.41      0.39       137
#
#     accuracy                           0.73       640
#    macro avg       0.60      0.61      0.61       640
# weighted avg       0.74      0.72      0.73       640
#
# ROC-AUC = 0.683		AP = 0.399
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.79      0.85      0.82       387
#         True       0.59      0.49      0.53       175
#
#     accuracy                           0.74       562
#    macro avg       0.69      0.67      0.68       562
# weighted avg       0.73      0.74      0.73       562
#
# ROC-AUC = 0.717		AP = 0.586
# ----------------------------------------------------
# guitar
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.78      0.97      0.86       150
#         True       0.98      0.85      0.91       286
#
#     accuracy                           0.89       436
#    macro avg       0.88      0.91      0.89       436
# weighted avg       0.91      0.89      0.90       436
#
# ROC-AUC = 0.973		AP = 0.987
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.86      0.68      0.76       310
#         True       0.46      0.71      0.56       121
#
#     accuracy                           0.69       431
#    macro avg       0.66      0.69      0.66       431
# weighted avg       0.75      0.69      0.70       431
#
# ROC-AUC = 0.746		AP = 0.551
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.65      0.94      0.77       130
#         True       0.96      0.77      0.86       285
#
#     accuracy                           0.82       415
#    macro avg       0.81      0.86      0.81       415
# weighted avg       0.87      0.82      0.83       415
#
# ROC-AUC = 0.940		AP = 0.973
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.76      0.78      0.77       324
#         True       0.76      0.73      0.75       305
#
#     accuracy                           0.76       629
#    macro avg       0.76      0.76      0.76       629
# weighted avg       0.76      0.76      0.76       629
#
# ROC-AUC = 0.834		AP = 0.820
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.73      0.84      0.78       467
#         True       0.70      0.55      0.62       318
#
#     accuracy                           0.72       785
#    macro avg       0.72      0.70      0.70       785
# weighted avg       0.72      0.72      0.72       785
#
# ROC-AUC = 0.784		AP = 0.708
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.66      0.86      0.75       237
#         True       0.90      0.74      0.81       394
#
#     accuracy                           0.78       631
#    macro avg       0.78      0.80      0.78       631
# weighted avg       0.81      0.78      0.79       631
#
# ROC-AUC = 0.865		AP = 0.918
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.77      0.97      0.86       150
#         True       0.97      0.80      0.88       224
#
#     accuracy                           0.87       374
#    macro avg       0.87      0.89      0.87       374
# weighted avg       0.89      0.87      0.87       374
#
# ROC-AUC = 0.966		AP = 0.978

# %% [markdown]
# # openmic->irmas

# %%
X_train = X_train_openmic
X_test = X_test_irmas

Y_true_train = Y_true_train_openmic
Y_true_test = Y_true_test_irmas

# standardize embedding
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print(X_train.shape, X_test.shape)
# Out:
# (14915, 1024) (1666, 1024)

# %%
# kernelize embedding with fastfood
Sampler = Fastfood(n_components=4*X_train.shape[1], random_state=0,
                                sigma=np.median(pairwise_distances(X_train, metric='l2')))
X_train = Sampler.fit_transform(X_train)
X_test = Sampler.transform(X_test)

Xdeb_train = X_train.dot(np.eye(len(A)) - A)
Xdeb_test = X_test.dot(np.eye(len(A)) - A)
print(Xdeb_train.shape, Xdeb_test.shape)

X_train = Xdeb_train; X_test = Xdeb_test; del(Xdeb_train, Xdeb_test)
print(X_train.shape, X_test.shape)
# Out:
# (14915, 8192) (1666, 8192)
# (14915, 8192) (1666, 8192)

# %%
train_set_name, test_set_name = 'openmic', 'irmas' 

# iterate over all istrument classes, and fit a model for each one
for instrument in class_align:
    
    # get the training and testing labels for each instrument
    Y_true_test_inst = Y_true_test==instrument

    # evaluate the classifier
    Y_pred_test_inst =  globals()['models_'+train_set_name][instrument].predict(X_test)
    Y_pred_test_scores =  globals()['models_'+train_set_name][instrument].predict_proba(X_test)[:, 1]
    
    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_true_test_inst, Y_pred_test_inst))
    
    model_auc = roc_auc_score(Y_true_test_inst, Y_pred_test_scores)
    model_ap = average_precision_score(Y_true_test_inst, Y_pred_test_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_true_test_inst, Y_pred_test_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    
    report_accuracy = pd.DataFrame(classification_report(Y_true_test_inst, Y_pred_test_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.79      0.88      1572
#         True       0.19      0.86      0.32        94
#
#     accuracy                           0.79      1666
#    macro avg       0.59      0.82      0.60      1666
# weighted avg       0.94      0.79      0.85      1666
#
# ROC-AUC = 0.887		AP = 0.465
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.74      0.85      1539
#         True       0.21      0.83      0.34       127
#
#     accuracy                           0.75      1666
#    macro avg       0.60      0.79      0.59      1666
# weighted avg       0.92      0.75      0.81      1666
#
# ROC-AUC = 0.878		AP = 0.569
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.67      0.80      1545
#         True       0.17      0.85      0.28       121
#
#     accuracy                           0.69      1666
#    macro avg       0.58      0.76      0.54      1666
# weighted avg       0.92      0.69      0.76      1666
#
# ROC-AUC = 0.874		AP = 0.550
# ----------------------------------------------------
# guitar
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.93      0.86      0.89      1320
#         True       0.58      0.74      0.65       346
#
#     accuracy                           0.84      1666
#    macro avg       0.75      0.80      0.77      1666
# weighted avg       0.85      0.84      0.84      1666
#
# ROC-AUC = 0.899		AP = 0.705
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.90      0.92      0.91      1492
#         True       0.20      0.17      0.18       174
#
#     accuracy                           0.84      1666
#    macro avg       0.55      0.54      0.55      1666
# weighted avg       0.83      0.84      0.84      1666
#
# ROC-AUC = 0.537		AP = 0.137
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.72      0.83      1496
#         True       0.25      0.81      0.38       170
#
#     accuracy                           0.73      1666
#    macro avg       0.61      0.77      0.60      1666
# weighted avg       0.90      0.73      0.78      1666
#
# ROC-AUC = 0.864		AP = 0.656
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.81      0.88      1516
#         True       0.24      0.61      0.35       150
#
#     accuracy                           0.79      1666
#    macro avg       0.60      0.71      0.61      1666
# weighted avg       0.89      0.79      0.83      1666
#
# ROC-AUC = 0.798		AP = 0.316
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.81      0.89      1516
#         True       0.30      0.85      0.45       150
#
#     accuracy                           0.81      1666
#    macro avg       0.64      0.83      0.67      1666
# weighted avg       0.92      0.81      0.85      1666
#
# ROC-AUC = 0.911		AP = 0.649
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.74      0.84      1523
#         True       0.23      0.80      0.36       143
#
#     accuracy                           0.75      1666
#    macro avg       0.60      0.77      0.60      1666
# weighted avg       0.91      0.75      0.80      1666
#
# ROC-AUC = 0.851		AP = 0.440
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.86      0.92      1475
#         True       0.47      0.96      0.63       191
#
#     accuracy                           0.87      1666
#    macro avg       0.73      0.91      0.78      1666
# weighted avg       0.93      0.87      0.89      1666
#
# ROC-AUC = 0.982		AP = 0.895

# %% [markdown]
# # Plot result on each instrument

# %%
# save all result into a csv file
result_all.to_csv('results/result_' + embedding + debias_method + '.csv', index=False)

C_vggish = []

for inst in class_align:
    C_vggish.append(models_irmas[inst].best_estimator_.C)
    C_vggish.append(models_openmic[inst].best_estimator_.C)
    
print(max(C_vggish), min(C_vggish))
# Out:
# 100 0.1
