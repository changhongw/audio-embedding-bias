# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import librosa
from tqdm import tqdm_notebook as tqdm
import json
import pandas as pd
import pickle
import os
import h5py
import collections as cl
from ast import literal_eval
import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, roc_auc_score, average_precision_score
from sklearn.preprocessing import StandardScaler
import random
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
param_grid = {'C': [10**k for k in range(-10, 6, 2)]}  
scoring = 'roc_auc'; cv = 3; random_state=42
random.seed(random_state)

# %%
with open("genre_map.json", "r") as f: # only consider 10 classes of Openmic dataset
    genre_map = json.load(f)
aligned_genre = list(genre_map)[:-1]

with open("instrument_map.json", "r") as f: # only consider 10 classes of Openmic dataset
    instrument_map = json.load(f)

# %%
# use a Pandas DataFrame to record all results and save into a csv file later
result_all = pd.DataFrame({'instrument': [],
                          'train_set': [],
                          'test_set': [],
                          'precision': [],
                          'recall': [],
                          'f1-score': [],
                          'support': [],
                          'accuracy': [],
                          'roc_auc': [],
                          'ap': [],
                          'embedding': [],
                         })

# %% [markdown]
# # Load embeddings and align classes

# %%
embedding = 'vggish'
debias_method = '-lda'

# load embeddings
embeddings = h5py.File("embeddings.h5", "r")

# %%
###### IRMAS data ######
feature = np.array(embeddings["irmas"][embedding]["features"])
keys_ori = np.array(embeddings["irmas"][embedding]["keys"])
key_clip = np.unique(keys_ori)

feature_clip = []

for key in tqdm(key_clip):
    feature_clip.append(np.mean(feature[keys_ori[:]==key,:],axis=0))
    
feature_clip = np.array(feature_clip)
print(feature_clip.shape, key_clip.shape)
# Out:
#   0%|          | 0/6705 [00:00<?, ?it/s]
# (6705, 128) (6705,)

# %%
def load_feature(meta, feature_clip, key_clip):
    key_train = list(meta.loc[(meta['split'] == 'train')]['file_name'])
    key_test = list(meta.loc[(meta['split'] == 'test')]['file_name'])

    idx_train = [list(key_clip).index(item) for item in key_train]
    idx_test = [list(key_clip).index(item) for item in key_test]
   
    # cast the idx_* arrays to numpy structures
    idx_train = np.asarray(idx_train)
    idx_test = np.asarray(idx_test)

    # use the split indices to partition the features, labels, and masks
    X_train = feature_clip[idx_train,:]
    X_test = feature_clip[idx_test]

    Y_train = meta.loc[(meta['split'] == 'train')]['instrument'].values
    Y_test = meta.loc[(meta['split'] == 'test')]['instrument'].values

    genre_train = meta.loc[(meta['split'] == 'train')]['genre'].values
    genre_test = meta.loc[(meta['split'] == 'test')]['genre'].values

    return (X_train, Y_train), (X_test, Y_test), (genre_train, genre_test)

# %%
A_meta = pd.read_csv("A_meta.csv")
(X_train_A, Y_train_A), (X_test_A, Y_test_A), (genre_train_A, genre_test_A) = load_feature(A_meta, feature_clip, key_clip)
B_meta = pd.read_csv("B_meta.csv")
(X_train_B, Y_train_B), (X_test_B, Y_test_B), (genre_train_B, genre_test_B) = load_feature(B_meta, feature_clip, key_clip)

# %%
from proxy_A_distance import proxy_a_distance

Adistance_all = proxy_a_distance(X_train_A, X_train_B, verbose=False)

# %%
Adistance_all
# Out:
# 1.4461292897047087

# %%
Adistance_inst = []

for instrument in instrument_map:

    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_A
    Y_train_inst = Y_train_A_inst
    X_test_inst = X_test_A
    Y_test_inst = Y_test_A_inst

    # save dataset separation direction
    Adistance_inst.append(proxy_a_distance(X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst], verbose=False))

# %%
Adistance_inst
# Out:
# [1.3379310344827586,
#  0.09523809523809534,
#  0.11904761904761907,
#  0.8067226890756303,
#  1.7052631578947368,
#  1.046875,
#  0.1777777777777778,
#  1.1319148936170214,
#  1.3333333333333335,
#  0.06451612903225801,
#  1.7671232876712328]

# %%
Adistance_inst
# Out:
# [1.282051282051282,
#  0.6122448979591837,
#  0.707070707070707,
#  1.2808988764044944,
#  1.7155555555555555,
#  1.225,
#  0.13953488372093026,
#  0.5614035087719298,
#  1.0442477876106193,
#  0.6554621848739495,
#  1.929078014184397]

# %%
plt.plot(Adistance_inst)

# %%
from proxy_A_distance import proxy_a_distance
Adistance_before = proxy_a_distance(X_train_A, X_train_B, verbose=False)

train_set_name, test_set_name = 'A', 'A' 

globals()['Adistance_' + train_set_name] = dict()

for instrument in instrument_map:

    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_A
    Y_train_inst = Y_train_A_inst
    X_test_inst = X_test_A
    Y_test_inst = Y_test_A_inst

    ############### LDA ###############
    X_train_conca = np.vstack((X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst]))
    Y_A = np.zeros(len(X_train_A[Y_train_A_inst]))
    Y_B = np.ones(len(X_train_B[Y_train_B_inst]))
    Y_conca = np.hstack((Y_A, Y_B))

    LDA = LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto')
    LDA.fit(X_train_conca, Y_conca)

    v = LDA.coef_.copy()
    v /= np.sqrt(np.sum(v**2))
    A = np.outer(v, v)

    X_train_inst = X_train_inst.copy().dot(np.eye(len(A)) - A)
    X_test_inst = X_test_inst.copy().dot(np.eye(len(A)) - A)

# %% [markdown]
# # A -> A

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'A', 'A' 

globals()['LDAcoef_' + train_set_name] = dict()

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_A
    Y_train_inst = Y_train_A_inst
    X_test_inst = X_test_A
    Y_test_inst = Y_test_A_inst

    

    ############### LDA ###############
    X_train_conca = np.vstack((X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst]))
    Y_A = np.zeros(len(X_train_A[Y_train_A_inst]))
    Y_B = np.ones(len(X_train_B[Y_train_B_inst]))
    Y_conca = np.hstack((Y_A, Y_B))

    LDA = LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto')
    LDA.fit(X_train_conca, Y_conca)

    v = LDA.coef_.copy()
    v /= np.sqrt(np.sum(v**2))
    A = np.outer(v, v)

    X_train_inst = X_train_inst.copy().dot(np.eye(len(A)) - A)
    X_test_inst = X_test_inst.copy().dot(np.eye(len(A)) - A)

    # save dataset separation direction
    globals()['LDAcoef_' + train_set_name][instrument] = LDA.coef_.copy()

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)

with open('models/LDAcoef_' + train_set_name + '_' + embedding + debias_method + '.pickle', 'wb') as fdesc:
    pickle.dump(globals()['LDAcoef_'+train_set_name], fdesc)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.92      0.95       728
#         True       0.28      0.80      0.42        30
#
#     accuracy                           0.91       758
#    macro avg       0.64      0.86      0.68       758
# weighted avg       0.96      0.91      0.93       758
#
# ROC-AUC = 0.950		AP = 0.674
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.88      0.93       723
#         True       0.25      0.86      0.39        35
#
#     accuracy                           0.87       758
#    macro avg       0.62      0.87      0.66       758
# weighted avg       0.96      0.87      0.91       758
#
# ROC-AUC = 0.920		AP = 0.501
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.87      0.92       714
#         True       0.25      0.68      0.36        44
#
#     accuracy                           0.86       758
#    macro avg       0.61      0.78      0.64       758
# weighted avg       0.94      0.86      0.89       758
#
# ROC-AUC = 0.857		AP = 0.489
# ----------------------------------------------------
# guitar-ac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.93      0.96       660
#         True       0.66      0.90      0.76        98
#
#     accuracy                           0.93       758
#    macro avg       0.82      0.91      0.86       758
# weighted avg       0.94      0.93      0.93       758
#
# ROC-AUC = 0.964		AP = 0.879
# ----------------------------------------------------
# guitar-el
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.86      0.91       628
#         True       0.55      0.82      0.66       130
#
#     accuracy                           0.85       758
#    macro avg       0.76      0.84      0.78       758
# weighted avg       0.89      0.85      0.87       758
#
# ROC-AUC = 0.921		AP = 0.749
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.89      0.94       684
#         True       0.46      0.85      0.60        74
#
#     accuracy                           0.89       758
#    macro avg       0.72      0.87      0.77       758
# weighted avg       0.93      0.89      0.90       758
#
# ROC-AUC = 0.938		AP = 0.679
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.93      0.95       719
#         True       0.33      0.67      0.44        39
#
#     accuracy                           0.91       758
#    macro avg       0.66      0.80      0.70       758
# weighted avg       0.95      0.91      0.93       758
#
# ROC-AUC = 0.919		AP = 0.577
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.86      0.92       723
#         True       0.20      0.71      0.31        35
#
#     accuracy                           0.85       758
#    macro avg       0.59      0.79      0.61       758
# weighted avg       0.95      0.85      0.89       758
#
# ROC-AUC = 0.833		AP = 0.325
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.87      0.92       717
#         True       0.22      0.61      0.32        41
#
#     accuracy                           0.86       758
#    macro avg       0.60      0.74      0.62       758
# weighted avg       0.93      0.86      0.89       758
#
# ROC-AUC = 0.845		AP = 0.471
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.32      0.49       712
#         True       0.08      0.96      0.15        46
#
#     accuracy                           0.36       758
#    macro avg       0.54      0.64      0.32       758
# weighted avg       0.94      0.36      0.47       758
#
# ROC-AUC = 0.842		AP = 0.506
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.94      0.96       572
#         True       0.84      0.93      0.88       186
#
#     accuracy                           0.94       758
#    macro avg       0.91      0.94      0.92       758
# weighted avg       0.94      0.94      0.94       758
#
# ROC-AUC = 0.980		AP = 0.955

# %% [markdown]
# # A -> B

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'A', 'B' 

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_A
    Y_train_inst = Y_train_A_inst
    X_test_inst = X_test_B
    Y_test_inst = Y_test_B_inst

    ############### LDA ###############
    X_train_conca = np.vstack((X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst]))
    Y_A = np.zeros(len(X_train_A[Y_train_A_inst]))
    Y_B = np.ones(len(X_train_B[Y_train_B_inst]))
    Y_conca = np.hstack((Y_A, Y_B))

    LDA = LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto')
    LDA.fit(X_train_conca, Y_conca)

    v = LDA.coef_.copy()
    v /= np.sqrt(np.sum(v**2))
    A = np.outer(v, v)

    X_train_inst = X_train_inst.copy().dot(np.eye(len(A)) - A)
    X_test_inst = X_test_inst.copy().dot(np.eye(len(A)) - A)

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.93      0.95       867
#         True       0.35      0.46      0.40        68
#
#     accuracy                           0.90       935
#    macro avg       0.65      0.70      0.67       935
# weighted avg       0.91      0.90      0.91       935
#
# ROC-AUC = 0.807		AP = 0.427
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.65      0.78       843
#         True       0.21      0.83      0.33        92
#
#     accuracy                           0.67       935
#    macro avg       0.59      0.74      0.56       935
# weighted avg       0.90      0.67      0.74       935
#
# ROC-AUC = 0.825		AP = 0.344
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.78      0.87       864
#         True       0.24      0.86      0.38        71
#
#     accuracy                           0.78       935
#    macro avg       0.61      0.82      0.62       935
# weighted avg       0.93      0.78      0.83       935
#
# ROC-AUC = 0.897		AP = 0.537
# ----------------------------------------------------
# guitar-ac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.96      0.98       872
#         True       0.61      0.95      0.75        63
#
#     accuracy                           0.96       935
#    macro avg       0.80      0.95      0.86       935
# weighted avg       0.97      0.96      0.96       935
#
# ROC-AUC = 0.988		AP = 0.902
# ----------------------------------------------------
# guitar-el
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.96      0.95       873
#         True       0.35      0.32      0.34        62
#
#     accuracy                           0.92       935
#    macro avg       0.65      0.64      0.65       935
# weighted avg       0.91      0.92      0.91       935
#
# ROC-AUC = 0.783		AP = 0.362
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.85      0.92       838
#         True       0.42      0.92      0.58        97
#
#     accuracy                           0.86       935
#    macro avg       0.70      0.89      0.75       935
# weighted avg       0.93      0.86      0.88       935
#
# ROC-AUC = 0.953		AP = 0.731
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.94      0.93      0.93       792
#         True       0.63      0.66      0.64       143
#
#     accuracy                           0.89       935
#    macro avg       0.78      0.79      0.79       935
# weighted avg       0.89      0.89      0.89       935
#
# ROC-AUC = 0.914		AP = 0.727
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.93      0.85      0.89       812
#         True       0.36      0.56      0.44       123
#
#     accuracy                           0.81       935
#    macro avg       0.64      0.70      0.66       935
# weighted avg       0.85      0.81      0.83       935
#
# ROC-AUC = 0.746		AP = 0.360
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.70      0.81       830
#         True       0.26      0.81      0.39       105
#
#     accuracy                           0.71       935
#    macro avg       0.61      0.76      0.60       935
# weighted avg       0.89      0.71      0.77       935
#
# ROC-AUC = 0.851		AP = 0.580
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.21      0.35       834
#         True       0.13      0.99      0.23       101
#
#     accuracy                           0.30       935
#    macro avg       0.56      0.60      0.29       935
# weighted avg       0.90      0.30      0.34       935
#
# ROC-AUC = 0.848		AP = 0.509
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99       925
#         True       0.30      0.60      0.40        10
#
#     accuracy                           0.98       935
#    macro avg       0.65      0.79      0.70       935
# weighted avg       0.99      0.98      0.98       935
#
# ROC-AUC = 0.929		AP = 0.295

# %% [markdown]
# # B -> B

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'B', 'B' 

globals()['LDAcoef_' + train_set_name] = dict()

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_B
    Y_train_inst = Y_train_B_inst
    X_test_inst = X_test_B
    Y_test_inst = Y_test_B_inst

    ############### LDA ###############
    X_train_conca = np.vstack((X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst]))
    Y_A = np.zeros(len(X_train_A[Y_train_A_inst]))
    Y_B = np.ones(len(X_train_B[Y_train_B_inst]))
    Y_conca = np.hstack((Y_A, Y_B))

    LDA = LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto')
    LDA.fit(X_train_conca, Y_conca)

    v = LDA.coef_.copy()
    v /= np.sqrt(np.sum(v**2))
    A = np.outer(v, v)

    X_train_inst = X_train_inst.copy().dot(np.eye(len(A)) - A)
    X_test_inst = X_test_inst.copy().dot(np.eye(len(A)) - A)

    # save dataset separation direction
    globals()['LDAcoef_' + train_set_name][instrument] = LDA.coef_.copy()

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)

with open('models/LDAcoef_' + train_set_name + '_' + embedding + debias_method + '.pickle', 'wb') as fdesc:
    pickle.dump(globals()['LDAcoef_'+train_set_name], fdesc)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.88      0.93       867
#         True       0.35      0.81      0.49        68
#
#     accuracy                           0.88       935
#    macro avg       0.67      0.85      0.71       935
# weighted avg       0.94      0.88      0.90       935
#
# ROC-AUC = 0.913		AP = 0.607
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.85      0.90       843
#         True       0.35      0.75      0.48        92
#
#     accuracy                           0.84       935
#    macro avg       0.66      0.80      0.69       935
# weighted avg       0.91      0.84      0.86       935
#
# ROC-AUC = 0.904		AP = 0.553
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.87      0.92       864
#         True       0.35      0.87      0.50        71
#
#     accuracy                           0.87       935
#    macro avg       0.67      0.87      0.71       935
# weighted avg       0.94      0.87      0.89       935
#
# ROC-AUC = 0.942		AP = 0.613
# ----------------------------------------------------
# guitar-ac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       872
#         True       0.70      0.86      0.77        63
#
#     accuracy                           0.97       935
#    macro avg       0.85      0.92      0.88       935
# weighted avg       0.97      0.97      0.97       935
#
# ROC-AUC = 0.980		AP = 0.877
# ----------------------------------------------------
# guitar-el
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.89      0.94       873
#         True       0.35      0.85      0.50        62
#
#     accuracy                           0.89       935
#    macro avg       0.67      0.87      0.72       935
# weighted avg       0.95      0.89      0.91       935
#
# ROC-AUC = 0.945		AP = 0.570
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.90      0.94       838
#         True       0.52      0.98      0.68        97
#
#     accuracy                           0.91       935
#    macro avg       0.76      0.94      0.81       935
# weighted avg       0.95      0.91      0.92       935
#
# ROC-AUC = 0.981		AP = 0.854
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.96      0.97       792
#         True       0.79      0.92      0.85       143
#
#     accuracy                           0.95       935
#    macro avg       0.89      0.94      0.91       935
# weighted avg       0.96      0.95      0.95       935
#
# ROC-AUC = 0.983		AP = 0.933
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.83      0.89       812
#         True       0.41      0.77      0.54       123
#
#     accuracy                           0.82       935
#    macro avg       0.68      0.80      0.71       935
# weighted avg       0.89      0.82      0.84       935
#
# ROC-AUC = 0.885		AP = 0.627
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.89      0.93       830
#         True       0.46      0.77      0.58       105
#
#     accuracy                           0.87       935
#    macro avg       0.71      0.83      0.75       935
# weighted avg       0.91      0.87      0.89       935
#
# ROC-AUC = 0.922		AP = 0.723
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.22      0.36       834
#         True       0.13      0.96      0.23       101
#
#     accuracy                           0.30       935
#    macro avg       0.55      0.59      0.30       935
# weighted avg       0.89      0.30      0.35       935
#
# ROC-AUC = 0.860		AP = 0.608
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       925
#         True       0.80      0.80      0.80        10
#
#     accuracy                           1.00       935
#    macro avg       0.90      0.90      0.90       935
# weighted avg       1.00      1.00      1.00       935
#
# ROC-AUC = 0.989		AP = 0.788

# %% [markdown]
# # B -> A

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'B', 'A' 

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_B
    Y_train_inst = Y_train_B_inst
    X_test_inst = X_test_A
    Y_test_inst = Y_test_A_inst

    ############### LDA ###############
    X_train_conca = np.vstack((X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst]))
    Y_A = np.zeros(len(X_train_A[Y_train_A_inst]))
    Y_B = np.ones(len(X_train_B[Y_train_B_inst]))
    Y_conca = np.hstack((Y_A, Y_B))

    LDA = LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto')
    LDA.fit(X_train_conca, Y_conca)

    v = LDA.coef_.copy()
    v /= np.sqrt(np.sum(v**2))
    A = np.outer(v, v)

    X_train_inst = X_train_inst.copy().dot(np.eye(len(A)) - A)
    X_test_inst = X_test_inst.copy().dot(np.eye(len(A)) - A)

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.98      0.98       728
#         True       0.38      0.33      0.36        30
#
#     accuracy                           0.95       758
#    macro avg       0.68      0.66      0.67       758
# weighted avg       0.95      0.95      0.95       758
#
# ROC-AUC = 0.781		AP = 0.333
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.91      0.94       723
#         True       0.24      0.60      0.35        35
#
#     accuracy                           0.90       758
#    macro avg       0.61      0.76      0.65       758
# weighted avg       0.95      0.90      0.92       758
#
# ROC-AUC = 0.817		AP = 0.314
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.92      0.94       714
#         True       0.29      0.55      0.38        44
#
#     accuracy                           0.90       758
#    macro avg       0.63      0.73      0.66       758
# weighted avg       0.93      0.90      0.91       758
#
# ROC-AUC = 0.860		AP = 0.467
# ----------------------------------------------------
# guitar-ac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.97      0.96       660
#         True       0.76      0.68      0.72        98
#
#     accuracy                           0.93       758
#    macro avg       0.86      0.83      0.84       758
# weighted avg       0.93      0.93      0.93       758
#
# ROC-AUC = 0.928		AP = 0.790
# ----------------------------------------------------
# guitar-el
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.89      0.64      0.74       628
#         True       0.26      0.62      0.37       130
#
#     accuracy                           0.64       758
#    macro avg       0.58      0.63      0.56       758
# weighted avg       0.78      0.64      0.68       758
#
# ROC-AUC = 0.677		AP = 0.257
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.65      0.79       684
#         True       0.22      0.91      0.35        74
#
#     accuracy                           0.68       758
#    macro avg       0.60      0.78      0.57       758
# weighted avg       0.91      0.68      0.74       758
#
# ROC-AUC = 0.884		AP = 0.505
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.96      0.97       719
#         True       0.45      0.56      0.50        39
#
#     accuracy                           0.94       758
#    macro avg       0.71      0.76      0.73       758
# weighted avg       0.95      0.94      0.95       758
#
# ROC-AUC = 0.891		AP = 0.554
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.93      0.95       723
#         True       0.27      0.57      0.37        35
#
#     accuracy                           0.91       758
#    macro avg       0.63      0.75      0.66       758
# weighted avg       0.95      0.91      0.92       758
#
# ROC-AUC = 0.855		AP = 0.399
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.93      0.95       717
#         True       0.27      0.41      0.32        41
#
#     accuracy                           0.91       758
#    macro avg       0.62      0.67      0.64       758
# weighted avg       0.93      0.91      0.92       758
#
# ROC-AUC = 0.776		AP = 0.380
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.06      0.12       712
#         True       0.06      1.00      0.12        46
#
#     accuracy                           0.12       758
#    macro avg       0.53      0.53      0.12       758
# weighted avg       0.94      0.12      0.12       758
#
# ROC-AUC = 0.818		AP = 0.503
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.90      0.97      0.93       572
#         True       0.88      0.66      0.75       186
#
#     accuracy                           0.89       758
#    macro avg       0.89      0.82      0.84       758
# weighted avg       0.89      0.89      0.89       758
#
# ROC-AUC = 0.937		AP = 0.882

# %% [markdown]
# # save result

# %%
# save all result into a csv file
# result_all.to_csv('results/result_' + embedding + debias_method + '_trainboth.csv', index=False)
# result_all.to_csv('results/result_' + embedding +  debias_method + '.csv', index=False)

# %%
# save all result into a csv file
df_1 = pd.read_csv('results/result_' + embedding + '.csv')

df = df_1.append(result_all)
df.to_csv('results/result_' + embedding  + debias_method + '.csv', index=False)

df = pd.read_csv('results/result_' + embedding  + debias_method + '.csv')

sns.set_theme(context='notebook', style='whitegrid', palette='deep')

sns.catplot(data=df, row='train_set', col='test_set', y='instrument', x='roc_auc', hue='embedding', kind='bar', 
            height=4, aspect=1.2)
plt.xlim([0.4,1])
plt.savefig('results/' + embedding  + debias_method + '.pdf')
