# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import librosa
from tqdm import tqdm_notebook as tqdm
import json
import pandas as pd
import pickle
import os
import h5py
import collections as cl
from ast import literal_eval
import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, roc_auc_score, average_precision_score
from sklearn.preprocessing import StandardScaler
import random
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
param_grid = {'C': [10**k for k in range(-10, 6, 2)]}  
scoring = 'roc_auc'; cv = 3; random_state=42
random.seed(random_state)

# %%
with open("genre_map.json", "r") as f: # only consider 10 classes of Openmic dataset
    genre_map = json.load(f)
aligned_genre = list(genre_map)[:-1]

with open("instrument_map.json", "r") as f: # only consider 10 classes of Openmic dataset
    instrument_map = json.load(f)

# %%
# use a Pandas DataFrame to record all results and save into a csv file later
result_all = pd.DataFrame({'instrument': [],
                          'train_set': [],
                          'test_set': [],
                          'precision': [],
                          'recall': [],
                          'f1-score': [],
                          'support': [],
                          'accuracy': [],
                          'roc_auc': [],
                          'ap': [],
                          'embedding': [],
                         })

# %% [markdown]
# # Load embeddings and align classes

# %%
embedding = 'yamnet'
debias_method = '-lda'

# load embeddings
embeddings = h5py.File("embeddings.h5", "r")

# %%
###### IRMAS data ######
feature = np.array(embeddings["irmas"][embedding]["features"])
keys_ori = np.array(embeddings["irmas"][embedding]["keys"])
key_clip = np.unique(keys_ori)

feature_clip = []

for key in tqdm(key_clip):
    feature_clip.append(np.mean(feature[keys_ori[:]==key,:],axis=0))
    
feature_clip = np.array(feature_clip)
print(feature_clip.shape, key_clip.shape)
# Out:
#   0%|          | 0/6705 [00:00<?, ?it/s]
# (6705, 1024) (6705,)

# %%
def load_feature(meta, feature_clip, key_clip):
    key_train = list(meta.loc[(meta['split'] == 'train')]['file_name'])
    key_test = list(meta.loc[(meta['split'] == 'test')]['file_name'])

    idx_train = [list(key_clip).index(item) for item in key_train]
    idx_test = [list(key_clip).index(item) for item in key_test]
   
    # cast the idx_* arrays to numpy structures
    idx_train = np.asarray(idx_train)
    idx_test = np.asarray(idx_test)

    # use the split indices to partition the features, labels, and masks
    X_train = feature_clip[idx_train,:]
    X_test = feature_clip[idx_test]

    Y_train = meta.loc[(meta['split'] == 'train')]['instrument'].values
    Y_test = meta.loc[(meta['split'] == 'test')]['instrument'].values

    genre_train = meta.loc[(meta['split'] == 'train')]['genre'].values
    genre_test = meta.loc[(meta['split'] == 'test')]['genre'].values

    return (X_train, Y_train), (X_test, Y_test), (genre_train, genre_test)

# %%
A_meta = pd.read_csv("A_meta.csv")
(X_train_A, Y_train_A), (X_test_A, Y_test_A), (genre_train_A, genre_test_A) = load_feature(A_meta, feature_clip, key_clip)
B_meta = pd.read_csv("B_meta.csv")
(X_train_B, Y_train_B), (X_test_B, Y_test_B), (genre_train_B, genre_test_B) = load_feature(B_meta, feature_clip, key_clip)

# %% [markdown]
# # A -> A

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'A', 'A' 

globals()['LDAcoef_' + train_set_name] = dict()

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_A
    Y_train_inst = Y_train_A_inst
    X_test_inst = X_test_A
    Y_test_inst = Y_test_A_inst

    ############### LDA ###############
    X_train_conca = np.vstack((X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst]))
    Y_A = np.zeros(len(X_train_A[Y_train_A_inst]))
    Y_B = np.ones(len(X_train_B[Y_train_B_inst]))
    Y_conca = np.hstack((Y_A, Y_B))

    LDA = LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto')
    LDA.fit(X_train_conca, Y_conca)

    v = LDA.coef_.copy()
    v /= np.sqrt(np.sum(v**2))
    A = np.outer(v, v)

    X_train_inst = X_train_inst.copy().dot(np.eye(len(A)) - A)
    X_test_inst = X_test_inst.copy().dot(np.eye(len(A)) - A)

    # save dataset separation direction
    globals()['LDAcoef_' + train_set_name][instrument] = LDA.coef_.copy()

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)

with open('models/LDAcoef_' + train_set_name + '_' + embedding + debias_method + '.pickle', 'wb') as fdesc:
    pickle.dump(globals()['LDAcoef_'+train_set_name], fdesc)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       728
#         True       0.47      0.67      0.55        30
#
#     accuracy                           0.96       758
#    macro avg       0.73      0.82      0.76       758
# weighted avg       0.97      0.96      0.96       758
#
# ROC-AUC = 0.928		AP = 0.608
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.96      0.98       723
#         True       0.52      0.80      0.63        35
#
#     accuracy                           0.96       758
#    macro avg       0.75      0.88      0.80       758
# weighted avg       0.97      0.96      0.96       758
#
# ROC-AUC = 0.977		AP = 0.779
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.93      0.95       714
#         True       0.38      0.68      0.49        44
#
#     accuracy                           0.92       758
#    macro avg       0.68      0.81      0.72       758
# weighted avg       0.94      0.92      0.93       758
#
# ROC-AUC = 0.921		AP = 0.650
# ----------------------------------------------------
# guitar-ac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.95      0.97       660
#         True       0.75      0.94      0.83        98
#
#     accuracy                           0.95       758
#    macro avg       0.87      0.95      0.90       758
# weighted avg       0.96      0.95      0.95       758
#
# ROC-AUC = 0.990		AP = 0.946
# ----------------------------------------------------
# guitar-el
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.90      0.93       628
#         True       0.64      0.89      0.75       130
#
#     accuracy                           0.90       758
#    macro avg       0.81      0.89      0.84       758
# weighted avg       0.92      0.90      0.90       758
#
# ROC-AUC = 0.952		AP = 0.811
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.95      0.96       684
#         True       0.63      0.84      0.72        74
#
#     accuracy                           0.94       758
#    macro avg       0.81      0.89      0.84       758
# weighted avg       0.95      0.94      0.94       758
#
# ROC-AUC = 0.970		AP = 0.804
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.96      0.97       719
#         True       0.48      0.72      0.58        39
#
#     accuracy                           0.95       758
#    macro avg       0.73      0.84      0.77       758
# weighted avg       0.96      0.95      0.95       758
#
# ROC-AUC = 0.966		AP = 0.727
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.96      0.97       723
#         True       0.41      0.51      0.46        35
#
#     accuracy                           0.94       758
#    macro avg       0.69      0.74      0.71       758
# weighted avg       0.95      0.94      0.95       758
#
# ROC-AUC = 0.850		AP = 0.488
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       717
#         True       0.55      0.76      0.64        41
#
#     accuracy                           0.95       758
#    macro avg       0.77      0.86      0.81       758
# weighted avg       0.96      0.95      0.96       758
#
# ROC-AUC = 0.930		AP = 0.689
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.88      0.93       712
#         True       0.29      0.74      0.41        46
#
#     accuracy                           0.87       758
#    macro avg       0.63      0.81      0.67       758
# weighted avg       0.94      0.87      0.90       758
#
# ROC-AUC = 0.907		AP = 0.538
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.96      0.97       572
#         True       0.89      0.96      0.92       186
#
#     accuracy                           0.96       758
#    macro avg       0.94      0.96      0.95       758
# weighted avg       0.96      0.96      0.96       758
#
# ROC-AUC = 0.989		AP = 0.979

# %% [markdown]
# # A -> B

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'A', 'B' 

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_A
    Y_train_inst = Y_train_A_inst
    X_test_inst = X_test_B
    Y_test_inst = Y_test_B_inst

    ############### LDA ###############
    X_train_conca = np.vstack((X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst]))
    Y_A = np.zeros(len(X_train_A[Y_train_A_inst]))
    Y_B = np.ones(len(X_train_B[Y_train_B_inst]))
    Y_conca = np.hstack((Y_A, Y_B))

    LDA = LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto')
    LDA.fit(X_train_conca, Y_conca)

    v = LDA.coef_.copy()
    v /= np.sqrt(np.sum(v**2))
    A = np.outer(v, v)

    X_train_inst = X_train_inst.copy().dot(np.eye(len(A)) - A)
    X_test_inst = X_test_inst.copy().dot(np.eye(len(A)) - A)

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.98      0.96       867
#         True       0.51      0.32      0.40        68
#
#     accuracy                           0.93       935
#    macro avg       0.73      0.65      0.68       935
# weighted avg       0.92      0.93      0.92       935
#
# ROC-AUC = 0.817		AP = 0.433
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.91      0.93       843
#         True       0.42      0.61      0.50        92
#
#     accuracy                           0.88       935
#    macro avg       0.69      0.76      0.71       935
# weighted avg       0.90      0.88      0.89       935
#
# ROC-AUC = 0.877		AP = 0.562
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.92      0.95       864
#         True       0.44      0.77      0.56        71
#
#     accuracy                           0.91       935
#    macro avg       0.71      0.85      0.75       935
# weighted avg       0.94      0.91      0.92       935
#
# ROC-AUC = 0.931		AP = 0.634
# ----------------------------------------------------
# guitar-ac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       872
#         True       0.64      0.81      0.71        63
#
#     accuracy                           0.96       935
#    macro avg       0.81      0.89      0.84       935
# weighted avg       0.96      0.96      0.96       935
#
# ROC-AUC = 0.970		AP = 0.807
# ----------------------------------------------------
# guitar-el
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.97      0.97       873
#         True       0.52      0.42      0.46        62
#
#     accuracy                           0.94       935
#    macro avg       0.74      0.70      0.72       935
# weighted avg       0.93      0.94      0.93       935
#
# ROC-AUC = 0.864		AP = 0.428
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.90      0.94       838
#         True       0.51      0.91      0.66        97
#
#     accuracy                           0.90       935
#    macro avg       0.75      0.90      0.80       935
# weighted avg       0.94      0.90      0.91       935
#
# ROC-AUC = 0.971		AP = 0.872
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.95      0.96       792
#         True       0.75      0.89      0.81       143
#
#     accuracy                           0.94       935
#    macro avg       0.87      0.92      0.89       935
# weighted avg       0.94      0.94      0.94       935
#
# ROC-AUC = 0.979		AP = 0.907
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.89      0.96      0.92       812
#         True       0.47      0.25      0.33       123
#
#     accuracy                           0.86       935
#    macro avg       0.68      0.60      0.63       935
# weighted avg       0.84      0.86      0.85       935
#
# ROC-AUC = 0.740		AP = 0.361
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.93      0.95       830
#         True       0.56      0.75      0.64       105
#
#     accuracy                           0.91       935
#    macro avg       0.76      0.84      0.79       935
# weighted avg       0.92      0.91      0.91       935
#
# ROC-AUC = 0.952		AP = 0.777
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.80      0.88       834
#         True       0.33      0.82      0.47       101
#
#     accuracy                           0.80       935
#    macro avg       0.65      0.81      0.68       935
# weighted avg       0.90      0.80      0.83       935
#
# ROC-AUC = 0.885		AP = 0.605
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.99      0.99       925
#         True       0.27      0.40      0.32        10
#
#     accuracy                           0.98       935
#    macro avg       0.63      0.69      0.66       935
# weighted avg       0.99      0.98      0.98       935
#
# ROC-AUC = 0.988		AP = 0.471

# %% [markdown]
# # B -> B

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'B', 'B' 

globals()['LDAcoef_' + train_set_name] = dict()

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_B
    Y_train_inst = Y_train_B_inst
    X_test_inst = X_test_B
    Y_test_inst = Y_test_B_inst

    ############### LDA ###############
    X_train_conca = np.vstack((X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst]))
    Y_A = np.zeros(len(X_train_A[Y_train_A_inst]))
    Y_B = np.ones(len(X_train_B[Y_train_B_inst]))
    Y_conca = np.hstack((Y_A, Y_B))

    LDA = LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto')
    LDA.fit(X_train_conca, Y_conca)

    v = LDA.coef_.copy()
    v /= np.sqrt(np.sum(v**2))
    A = np.outer(v, v)

    X_train_inst = X_train_inst.copy().dot(np.eye(len(A)) - A)
    X_test_inst = X_test_inst.copy().dot(np.eye(len(A)) - A)

    # save dataset separation direction
    globals()['LDAcoef_' + train_set_name][instrument] = LDA.coef_.copy()

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)

with open('models/LDAcoef_' + train_set_name + '_' + embedding + debias_method + '.pickle', 'wb') as fdesc:
    pickle.dump(globals()['LDAcoef_'+train_set_name], fdesc)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.92      0.96       867
#         True       0.48      0.90      0.63        68
#
#     accuracy                           0.92       935
#    macro avg       0.74      0.91      0.79       935
# weighted avg       0.95      0.92      0.93       935
#
# ROC-AUC = 0.974		AP = 0.818
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.90      0.94       843
#         True       0.46      0.79      0.58        92
#
#     accuracy                           0.89       935
#    macro avg       0.72      0.85      0.76       935
# weighted avg       0.92      0.89      0.90       935
#
# ROC-AUC = 0.938		AP = 0.747
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.91      0.94       864
#         True       0.42      0.80      0.55        71
#
#     accuracy                           0.90       935
#    macro avg       0.70      0.86      0.75       935
# weighted avg       0.94      0.90      0.91       935
#
# ROC-AUC = 0.946		AP = 0.659
# ----------------------------------------------------
# guitar-ac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.94      0.97       872
#         True       0.53      0.87      0.66        63
#
#     accuracy                           0.94       935
#    macro avg       0.76      0.91      0.81       935
# weighted avg       0.96      0.94      0.95       935
#
# ROC-AUC = 0.969		AP = 0.826
# ----------------------------------------------------
# guitar-el
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.94      0.96       873
#         True       0.50      0.84      0.63        62
#
#     accuracy                           0.93       935
#    macro avg       0.75      0.89      0.80       935
# weighted avg       0.96      0.93      0.94       935
#
# ROC-AUC = 0.974		AP = 0.754
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.93      0.96       838
#         True       0.63      0.97      0.76        97
#
#     accuracy                           0.94       935
#    macro avg       0.81      0.95      0.86       935
# weighted avg       0.96      0.94      0.94       935
#
# ROC-AUC = 0.990		AP = 0.937
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.98      0.98       792
#         True       0.88      0.94      0.91       143
#
#     accuracy                           0.97       935
#    macro avg       0.93      0.96      0.95       935
# weighted avg       0.97      0.97      0.97       935
#
# ROC-AUC = 0.993		AP = 0.964
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.89      0.93       812
#         True       0.53      0.82      0.64       123
#
#     accuracy                           0.88       935
#    macro avg       0.75      0.86      0.79       935
# weighted avg       0.91      0.88      0.89       935
#
# ROC-AUC = 0.941		AP = 0.772
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.96      0.97       830
#         True       0.72      0.90      0.80       105
#
#     accuracy                           0.95       935
#    macro avg       0.85      0.93      0.89       935
# weighted avg       0.96      0.95      0.95       935
#
# ROC-AUC = 0.977		AP = 0.905
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.95      0.95       834
#         True       0.59      0.62      0.61       101
#
#     accuracy                           0.91       935
#    macro avg       0.77      0.79      0.78       935
# weighted avg       0.91      0.91      0.91       935
#
# ROC-AUC = 0.928		AP = 0.702
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       925
#         True       1.00      0.70      0.82        10
#
#     accuracy                           1.00       935
#    macro avg       1.00      0.85      0.91       935
# weighted avg       1.00      1.00      1.00       935
#
# ROC-AUC = 0.999		AP = 0.942

# %% [markdown]
# # B -> A

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'B', 'A' 

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_B
    Y_train_inst = Y_train_B_inst
    X_test_inst = X_test_A
    Y_test_inst = Y_test_A_inst

    ############### LDA ###############
    X_train_conca = np.vstack((X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst]))
    Y_A = np.zeros(len(X_train_A[Y_train_A_inst]))
    Y_B = np.ones(len(X_train_B[Y_train_B_inst]))
    Y_conca = np.hstack((Y_A, Y_B))

    LDA = LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto')
    LDA.fit(X_train_conca, Y_conca)

    v = LDA.coef_.copy()
    v /= np.sqrt(np.sum(v**2))
    A = np.outer(v, v)

    X_train_inst = X_train_inst.copy().dot(np.eye(len(A)) - A)
    X_test_inst = X_test_inst.copy().dot(np.eye(len(A)) - A)

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
# Out:
# ----------------------------------------------------
# cello
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.97      0.98       728
#         True       0.43      0.50      0.46        30
#
#     accuracy                           0.95       758
#    macro avg       0.70      0.74      0.72       758
# weighted avg       0.96      0.95      0.96       758
#
# ROC-AUC = 0.908		AP = 0.491
# ----------------------------------------------------
# clarinet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.94      0.96       723
#         True       0.33      0.57      0.42        35
#
#     accuracy                           0.93       758
#    macro avg       0.66      0.76      0.69       758
# weighted avg       0.95      0.93      0.94       758
#
# ROC-AUC = 0.887		AP = 0.477
# ----------------------------------------------------
# flute
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.93      0.95       714
#         True       0.30      0.52      0.38        44
#
#     accuracy                           0.90       758
#    macro avg       0.64      0.72      0.67       758
# weighted avg       0.93      0.90      0.91       758
#
# ROC-AUC = 0.829		AP = 0.475
# ----------------------------------------------------
# guitar-ac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.87      0.92       660
#         True       0.50      0.86      0.63        98
#
#     accuracy                           0.87       758
#    macro avg       0.74      0.86      0.77       758
# weighted avg       0.91      0.87      0.88       758
#
# ROC-AUC = 0.948		AP = 0.824
# ----------------------------------------------------
# guitar-el
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.90      0.90      0.90       628
#         True       0.52      0.54      0.53       130
#
#     accuracy                           0.84       758
#    macro avg       0.71      0.72      0.72       758
# weighted avg       0.84      0.84      0.84       758
#
# ROC-AUC = 0.809		AP = 0.545
# ----------------------------------------------------
# organ
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.75      0.85       684
#         True       0.27      0.85      0.41        74
#
#     accuracy                           0.76       758
#    macro avg       0.62      0.80      0.63       758
# weighted avg       0.91      0.76      0.80       758
#
# ROC-AUC = 0.908		AP = 0.688
# ----------------------------------------------------
# piano
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.97      0.97       719
#         True       0.51      0.54      0.53        39
#
#     accuracy                           0.95       758
#    macro avg       0.74      0.76      0.75       758
# weighted avg       0.95      0.95      0.95       758
#
# ROC-AUC = 0.878		AP = 0.575
# ----------------------------------------------------
# saxophone
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.93      0.95       723
#         True       0.23      0.43      0.30        35
#
#     accuracy                           0.91       758
#    macro avg       0.60      0.68      0.63       758
# weighted avg       0.94      0.91      0.92       758
#
# ROC-AUC = 0.854		AP = 0.378
# ----------------------------------------------------
# trumpet
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.96      0.97       717
#         True       0.46      0.54      0.49        41
#
#     accuracy                           0.94       758
#    macro avg       0.72      0.75      0.73       758
# weighted avg       0.95      0.94      0.94       758
#
# ROC-AUC = 0.860		AP = 0.555
# ----------------------------------------------------
# violin
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.79      0.87       712
#         True       0.15      0.57      0.23        46
#
#     accuracy                           0.77       758
#    macro avg       0.56      0.68      0.55       758
# weighted avg       0.92      0.77      0.83       758
#
# ROC-AUC = 0.725		AP = 0.144
# ----------------------------------------------------
# voice
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.93      0.99      0.96       572
#         True       0.95      0.78      0.86       186
#
#     accuracy                           0.94       758
#    macro avg       0.94      0.89      0.91       758
# weighted avg       0.94      0.94      0.93       758
#
# ROC-AUC = 0.974		AP = 0.943

# %% [markdown]
# # save result

# %%
# save all result into a csv file
# result_all.to_csv('results/result_' + embedding + debias_method + '_trainboth.csv', index=False)
# result_all.to_csv('results/result_' + embedding +  debias_method + '.csv', index=False)

# %%
# save all result into a csv file
df_1 = pd.read_csv('results/result_' + embedding + '.csv')

df = df_1.append(result_all)
df.to_csv('results/result_' + embedding  + debias_method + '.csv', index=False)

df = pd.read_csv('results/result_' + embedding  + debias_method + '.csv')

sns.set_theme(context='notebook', style='whitegrid', palette='deep')

sns.catplot(data=df, row='train_set', col='test_set', y='instrument', x='roc_auc', hue='embedding', kind='bar', 
            height=4, aspect=1.2)
plt.xlim([0.4,1])
plt.savefig('results/' + embedding  + debias_method + '.pdf')
