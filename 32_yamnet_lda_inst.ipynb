# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import librosa
from tqdm import tqdm_notebook as tqdm
import json
import pandas as pd
import pickle
import os
import h5py
import collections as cl
from ast import literal_eval
import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, roc_auc_score, average_precision_score
from sklearn.preprocessing import StandardScaler
import random
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
param_grid = {'C': [10**k for k in range(-10, 6, 2)]}  
scoring = 'roc_auc'; cv = 3; random_state=42
random.seed(random_state)

# %%
with open("genre_map.json", "r") as f: # only consider 10 classes of Openmic dataset
    genre_map = json.load(f)
aligned_genre = list(genre_map)[:-1]

with open("instrument_map.json", "r") as f: # only consider 10 classes of Openmic dataset
    instrument_map = json.load(f)

# %%
# use a Pandas DataFrame to record all results and save into a csv file later
result_all = pd.DataFrame({'instrument': [],
                          'train_set': [],
                          'test_set': [],
                          'precision': [],
                          'recall': [],
                          'f1-score': [],
                          'support': [],
                          'accuracy': [],
                          'roc_auc': [],
                          'ap': [],
                          'embedding': [],
                         })

# %% [markdown]
# # Load embeddings and align classes

# %%
embedding = 'yamnet'
debias_method = '-lda'

# load embeddings
embeddings = h5py.File("embeddings.h5", "r")

# %%
###### IRMAS data ######
feature = np.array(embeddings["irmas"][embedding]["features"])
keys_ori = np.array(embeddings["irmas"][embedding]["keys"])
key_clip = np.unique(keys_ori)

feature_clip = []

for key in tqdm(key_clip):
    feature_clip.append(np.mean(feature[keys_ori[:]==key,:],axis=0))
    
feature_clip = np.array(feature_clip)
print(feature_clip.shape, key_clip.shape)
# Out:
#   0%|          | 0/6705 [00:00<?, ?it/s]
# (6705, 1024) (6705,)

# %%
def load_feature(meta, feature_clip, key_clip):
    key_train = list(meta.loc[(meta['split'] == 'train')]['file_name'])
    key_test = list(meta.loc[(meta['split'] == 'test')]['file_name'])

    idx_train = [list(key_clip).index(item) for item in key_train]
    idx_test = [list(key_clip).index(item) for item in key_test]
   
    # cast the idx_* arrays to numpy structures
    idx_train = np.asarray(idx_train)
    idx_test = np.asarray(idx_test)

    # use the split indices to partition the features, labels, and masks
    X_train = feature_clip[idx_train,:]
    X_test = feature_clip[idx_test]

    Y_train = meta.loc[(meta['split'] == 'train')]['instrument'].values
    Y_test = meta.loc[(meta['split'] == 'test')]['instrument'].values

    genre_train = meta.loc[(meta['split'] == 'train')]['genre'].values
    genre_test = meta.loc[(meta['split'] == 'test')]['genre'].values

    return (X_train, Y_train), (X_test, Y_test), (genre_train, genre_test)

# %%
A_meta = pd.read_csv("A_meta.csv")
(X_train_A, Y_train_A), (X_test_A, Y_test_A), (genre_train_A, genre_test_A) = load_feature(A_meta, feature_clip, key_clip)
B_meta = pd.read_csv("B_meta.csv")
(X_train_B, Y_train_B), (X_test_B, Y_test_B), (genre_train_B, genre_test_B) = load_feature(B_meta, feature_clip, key_clip)

# %% [markdown]
# # A -> A

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'A', 'A' 

globals()['LDAcoef_' + train_set_name] = dict()

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_A
    Y_train_inst = Y_train_A_inst
    X_test_inst = X_test_A
    Y_test_inst = Y_test_A_inst

    ############### LDA ###############
    X_train_conca = np.vstack((X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst]))
    Y_A = np.zeros(len(X_train_A[Y_train_A_inst]))
    Y_B = np.ones(len(X_train_B[Y_train_B_inst]))
    Y_conca = np.hstack((Y_A, Y_B))

    LDA = LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto')
    LDA.fit(X_train_conca, Y_conca)

    v = LDA.coef_.copy()
    v /= np.sqrt(np.sum(v**2))
    A = np.outer(v, v)

    X_train_inst = X_train_inst.copy().dot(np.eye(len(A)) - A)
    X_test_inst = X_test_inst.copy().dot(np.eye(len(A)) - A)

    # save dataset separation direction
    globals()['LDAcoef_' + train_set_name][instrument] = LDA.coef_.copy()

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)

with open('models/LDAcoef_' + train_set_name + '_' + embedding + debias_method + '.pickle', 'wb') as fdesc:
    pickle.dump(globals()['LDAcoef_'+train_set_name], fdesc)
# Out:
# ----------------------------------------------------
# cel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.92      0.96       728
#         True       0.31      0.83      0.45        30
#
#     accuracy                           0.92       758
#    macro avg       0.65      0.88      0.70       758
# weighted avg       0.97      0.92      0.94       758
#
# ROC-AUC = 0.943		AP = 0.491
# ----------------------------------------------------
# cla
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       723
#         True       0.51      0.74      0.60        35
#
#     accuracy                           0.96       758
#    macro avg       0.75      0.85      0.79       758
# weighted avg       0.97      0.96      0.96       758
#
# ROC-AUC = 0.965		AP = 0.724
# ----------------------------------------------------
# flu
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.86      0.92       714
#         True       0.26      0.77      0.39        44
#
#     accuracy                           0.86       758
#    macro avg       0.62      0.82      0.65       758
# weighted avg       0.94      0.86      0.89       758
#
# ROC-AUC = 0.892		AP = 0.638
# ----------------------------------------------------
# gac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.96      0.97       660
#         True       0.78      0.87      0.82        98
#
#     accuracy                           0.95       758
#    macro avg       0.88      0.92      0.90       758
# weighted avg       0.95      0.95      0.95       758
#
# ROC-AUC = 0.984		AP = 0.899
# ----------------------------------------------------
# gel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.90      0.93       628
#         True       0.63      0.85      0.72       130
#
#     accuracy                           0.89       758
#    macro avg       0.80      0.87      0.83       758
# weighted avg       0.91      0.89      0.89       758
#
# ROC-AUC = 0.954		AP = 0.851
# ----------------------------------------------------
# org
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.95      0.96       684
#         True       0.63      0.82      0.71        74
#
#     accuracy                           0.94       758
#    macro avg       0.80      0.89      0.84       758
# weighted avg       0.95      0.94      0.94       758
#
# ROC-AUC = 0.973		AP = 0.800
# ----------------------------------------------------
# pia
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.94      0.97       719
#         True       0.44      0.90      0.59        39
#
#     accuracy                           0.94       758
#    macro avg       0.72      0.92      0.78       758
# weighted avg       0.97      0.94      0.95       758
#
# ROC-AUC = 0.979		AP = 0.767
# ----------------------------------------------------
# sax
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.83      0.90       723
#         True       0.15      0.63      0.25        35
#
#     accuracy                           0.82       758
#    macro avg       0.57      0.73      0.57       758
# weighted avg       0.94      0.82      0.87       758
#
# ROC-AUC = 0.852		AP = 0.292
# ----------------------------------------------------
# tru
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.95      0.97       717
#         True       0.50      0.93      0.65        41
#
#     accuracy                           0.95       758
#    macro avg       0.75      0.94      0.81       758
# weighted avg       0.97      0.95      0.95       758
#
# ROC-AUC = 0.989		AP = 0.859
# ----------------------------------------------------
# vio
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.93      0.95       712
#         True       0.39      0.70      0.50        46
#
#     accuracy                           0.92       758
#    macro avg       0.68      0.81      0.73       758
# weighted avg       0.94      0.92      0.93       758
#
# ROC-AUC = 0.894		AP = 0.578
# ----------------------------------------------------
# voi
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.97      0.98       572
#         True       0.91      0.95      0.93       186
#
#     accuracy                           0.96       758
#    macro avg       0.94      0.96      0.95       758
# weighted avg       0.96      0.96      0.96       758
#
# ROC-AUC = 0.984		AP = 0.967

# %% [markdown]
# # A -> B

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'A', 'B' 

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_A
    Y_train_inst = Y_train_A_inst
    X_test_inst = X_test_B
    Y_test_inst = Y_test_B_inst

    ############### LDA ###############
    X_train_conca = np.vstack((X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst]))
    Y_A = np.zeros(len(X_train_A[Y_train_A_inst]))
    Y_B = np.ones(len(X_train_B[Y_train_B_inst]))
    Y_conca = np.hstack((Y_A, Y_B))

    LDA = LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto')
    LDA.fit(X_train_conca, Y_conca)

    v = LDA.coef_.copy()
    v /= np.sqrt(np.sum(v**2))
    A = np.outer(v, v)

    X_train_inst = X_train_inst.copy().dot(np.eye(len(A)) - A)
    X_test_inst = X_test_inst.copy().dot(np.eye(len(A)) - A)

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
# Out:
# ----------------------------------------------------
# cel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.90      0.95       867
#         True       0.42      0.90      0.58        68
#
#     accuracy                           0.90       935
#    macro avg       0.71      0.90      0.76       935
# weighted avg       0.95      0.90      0.92       935
#
# ROC-AUC = 0.957		AP = 0.782
# ----------------------------------------------------
# cla
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.89      0.92       843
#         True       0.35      0.55      0.43        92
#
#     accuracy                           0.86       935
#    macro avg       0.65      0.72      0.68       935
# weighted avg       0.89      0.86      0.87       935
#
# ROC-AUC = 0.824		AP = 0.489
# ----------------------------------------------------
# flu
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.78      0.87       864
#         True       0.25      0.93      0.40        71
#
#     accuracy                           0.79       935
#    macro avg       0.62      0.85      0.64       935
# weighted avg       0.94      0.79      0.84       935
#
# ROC-AUC = 0.932		AP = 0.639
# ----------------------------------------------------
# gac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.96      0.97       872
#         True       0.57      0.71      0.63        63
#
#     accuracy                           0.94       935
#    macro avg       0.77      0.84      0.80       935
# weighted avg       0.95      0.94      0.95       935
#
# ROC-AUC = 0.934		AP = 0.617
# ----------------------------------------------------
# gel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.98      0.97       873
#         True       0.63      0.39      0.48        62
#
#     accuracy                           0.94       935
#    macro avg       0.79      0.69      0.73       935
# weighted avg       0.94      0.94      0.94       935
#
# ROC-AUC = 0.889		AP = 0.523
# ----------------------------------------------------
# org
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.92      0.95       838
#         True       0.57      0.93      0.70        97
#
#     accuracy                           0.92       935
#    macro avg       0.78      0.92      0.83       935
# weighted avg       0.95      0.92      0.93       935
#
# ROC-AUC = 0.978		AP = 0.857
# ----------------------------------------------------
# pia
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.92      0.95       792
#         True       0.66      0.87      0.75       143
#
#     accuracy                           0.91       935
#    macro avg       0.82      0.90      0.85       935
# weighted avg       0.93      0.91      0.92       935
#
# ROC-AUC = 0.953		AP = 0.840
# ----------------------------------------------------
# sax
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.82      0.88       812
#         True       0.38      0.71      0.49       123
#
#     accuracy                           0.81       935
#    macro avg       0.66      0.76      0.69       935
# weighted avg       0.87      0.81      0.83       935
#
# ROC-AUC = 0.839		AP = 0.550
# ----------------------------------------------------
# tru
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.93      0.95       830
#         True       0.56      0.74      0.64       105
#
#     accuracy                           0.90       935
#    macro avg       0.76      0.83      0.79       935
# weighted avg       0.92      0.90      0.91       935
#
# ROC-AUC = 0.912		AP = 0.760
# ----------------------------------------------------
# vio
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.87      0.91       834
#         True       0.40      0.75      0.53       101
#
#     accuracy                           0.85       935
#    macro avg       0.69      0.81      0.72       935
# weighted avg       0.91      0.85      0.87       935
#
# ROC-AUC = 0.899		AP = 0.635
# ----------------------------------------------------
# voi
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      0.99       925
#         True       0.47      0.70      0.56        10
#
#     accuracy                           0.99       935
#    macro avg       0.73      0.85      0.78       935
# weighted avg       0.99      0.99      0.99       935
#
# ROC-AUC = 0.996		AP = 0.825

# %% [markdown]
# # B -> B

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'B', 'B' 

globals()['LDAcoef_' + train_set_name] = dict()

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_B
    Y_train_inst = Y_train_B_inst
    X_test_inst = X_test_B
    Y_test_inst = Y_test_B_inst

    ############### LDA ###############
    X_train_conca = np.vstack((X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst]))
    Y_A = np.zeros(len(X_train_A[Y_train_A_inst]))
    Y_B = np.ones(len(X_train_B[Y_train_B_inst]))
    Y_conca = np.hstack((Y_A, Y_B))

    LDA = LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto')
    LDA.fit(X_train_conca, Y_conca)

    v = LDA.coef_.copy()
    v /= np.sqrt(np.sum(v**2))
    A = np.outer(v, v)

    X_train_inst = X_train_inst.copy().dot(np.eye(len(A)) - A)
    X_test_inst = X_test_inst.copy().dot(np.eye(len(A)) - A)

    # save dataset separation direction
    globals()['LDAcoef_' + train_set_name][instrument] = LDA.coef_.copy()

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)

with open('models/LDAcoef_' + train_set_name + '_' + embedding + debias_method + '.pickle', 'wb') as fdesc:
    pickle.dump(globals()['LDAcoef_'+train_set_name], fdesc)
# Out:
# ----------------------------------------------------
# cel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.94      0.97       867
#         True       0.54      0.91      0.68        68
#
#     accuracy                           0.94       935
#    macro avg       0.77      0.93      0.82       935
# weighted avg       0.96      0.94      0.94       935
#
# ROC-AUC = 0.980		AP = 0.875
# ----------------------------------------------------
# cla
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.90      0.93       843
#         True       0.44      0.75      0.56        92
#
#     accuracy                           0.88       935
#    macro avg       0.71      0.82      0.74       935
# weighted avg       0.92      0.88      0.90       935
#
# ROC-AUC = 0.918		AP = 0.682
# ----------------------------------------------------
# flu
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.94      0.96       864
#         True       0.53      0.85      0.65        71
#
#     accuracy                           0.93       935
#    macro avg       0.76      0.89      0.81       935
# weighted avg       0.95      0.93      0.94       935
#
# ROC-AUC = 0.956		AP = 0.714
# ----------------------------------------------------
# gac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.94      0.96       872
#         True       0.49      0.83      0.62        63
#
#     accuracy                           0.93       935
#    macro avg       0.74      0.88      0.79       935
# weighted avg       0.95      0.93      0.94       935
#
# ROC-AUC = 0.960		AP = 0.790
# ----------------------------------------------------
# gel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       873
#         True       0.66      0.89      0.76        62
#
#     accuracy                           0.96       935
#    macro avg       0.83      0.93      0.87       935
# weighted avg       0.97      0.96      0.97       935
#
# ROC-AUC = 0.987		AP = 0.866
# ----------------------------------------------------
# org
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.94      0.97       838
#         True       0.65      0.99      0.78        97
#
#     accuracy                           0.94       935
#    macro avg       0.82      0.96      0.88       935
# weighted avg       0.96      0.94      0.95       935
#
# ROC-AUC = 0.995		AP = 0.957
# ----------------------------------------------------
# pia
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.96      0.98       792
#         True       0.83      0.94      0.88       143
#
#     accuracy                           0.96       935
#    macro avg       0.91      0.95      0.93       935
# weighted avg       0.96      0.96      0.96       935
#
# ROC-AUC = 0.987		AP = 0.935
# ----------------------------------------------------
# sax
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.89      0.92       812
#         True       0.51      0.80      0.62       123
#
#     accuracy                           0.87       935
#    macro avg       0.74      0.84      0.77       935
# weighted avg       0.91      0.87      0.88       935
#
# ROC-AUC = 0.934		AP = 0.755
# ----------------------------------------------------
# tru
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.93      0.95       830
#         True       0.59      0.86      0.70       105
#
#     accuracy                           0.92       935
#    macro avg       0.79      0.89      0.83       935
# weighted avg       0.94      0.92      0.92       935
#
# ROC-AUC = 0.974		AP = 0.873
# ----------------------------------------------------
# vio
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.84      0.90       834
#         True       0.36      0.76      0.49       101
#
#     accuracy                           0.83       935
#    macro avg       0.67      0.80      0.69       935
# weighted avg       0.90      0.83      0.85       935
#
# ROC-AUC = 0.854		AP = 0.584
# ----------------------------------------------------
# voi
# 	TEST
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      1.00       925
#         True       0.67      1.00      0.80        10
#
#     accuracy                           0.99       935
#    macro avg       0.83      1.00      0.90       935
# weighted avg       1.00      0.99      1.00       935
#
# ROC-AUC = 0.999		AP = 0.967

# %% [markdown]
# # B -> A

# %%
# This part of the code follows the baseline model for instrument recognition on the openmic dataset:
# https://github.com/cosmir/openmic-2018/blob/master/examples/modeling-baseline.ipynb
train_set_name, test_set_name = 'B', 'A' 

# We'll iterate over all istrument classes, and fit a model for each one
# After training, we'll print a classification report for each instrument
for instrument in instrument_map:
    
    Y_train_A_inst = Y_train_A==instrument
    Y_train_B_inst = Y_train_B==instrument

    Y_test_A_inst = Y_test_A==instrument
    Y_test_B_inst = Y_test_B==instrument

    X_train_inst = X_train_B
    Y_train_inst = Y_train_B_inst
    X_test_inst = X_test_A
    Y_test_inst = Y_test_A_inst

    ############### LDA ###############
    X_train_conca = np.vstack((X_train_A[Y_train_A_inst], X_train_B[Y_train_B_inst]))
    Y_A = np.zeros(len(X_train_A[Y_train_A_inst]))
    Y_B = np.ones(len(X_train_B[Y_train_B_inst]))
    Y_conca = np.hstack((Y_A, Y_B))

    LDA = LinearDiscriminantAnalysis(solver='eigen', shrinkage='auto')
    LDA.fit(X_train_conca, Y_conca)

    v = LDA.coef_.copy()
    v /= np.sqrt(np.sum(v**2))
    A = np.outer(v, v)

    X_train_inst = X_train_inst.copy().dot(np.eye(len(A)) - A)
    X_test_inst = X_test_inst.copy().dot(np.eye(len(A)) - A)

    # initialize and a logistic regression model
    LRmodel = LogisticRegression(random_state=random_state, penalty='l2', solver='liblinear', class_weight='balanced')
    
    # hyperparameter tunning for logistic regression model
    clf =  GridSearchCV(LRmodel, param_grid=param_grid, cv=cv, scoring=scoring)    
    
    # fit the model
    clf.fit(X_train_inst, Y_train_inst)

    # predict
    Y_pred_inst = clf.predict(X_test_inst)
    # Get prediction scores for the positive class
    Y_pred_scores = clf.predict_proba(X_test_inst)[:, 1]

    # print result for each instrument
    print('-' * 52); print(instrument); print('\tTEST')
    print(classification_report(Y_test_inst, Y_pred_inst))
    
    model_auc = roc_auc_score(Y_test_inst, Y_pred_scores)
    model_ap = average_precision_score(Y_test_inst, Y_pred_scores)
    print(f'ROC-AUC = {model_auc:.3f}\t\tAP = {model_ap:.3f}')
    
    # record the result for each instrument
    report = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['True']
    report['roc_auc'] = model_auc
    report['ap'] = model_ap
    report_accuracy = pd.DataFrame(classification_report(Y_test_inst, Y_pred_inst, output_dict=True))['accuracy'][-2]
    result_inst = [instrument, train_set_name, test_set_name, report['precision'], report['recall'],
                   report['f1-score'], report['support'], report_accuracy, model_auc, model_ap, embedding + debias_method]   
    result_all = result_all.append(pd.DataFrame(np.expand_dims(np.array(result_inst), axis=0), 
                                                columns=result_all.columns), ignore_index=True)
# Out:
# ----------------------------------------------------
# cel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.96      0.97       728
#         True       0.32      0.40      0.35        30
#
#     accuracy                           0.94       758
#    macro avg       0.65      0.68      0.66       758
# weighted avg       0.95      0.94      0.95       758
#
# ROC-AUC = 0.853		AP = 0.256
# ----------------------------------------------------
# cla
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.96      0.97       723
#         True       0.38      0.57      0.46        35
#
#     accuracy                           0.94       758
#    macro avg       0.68      0.76      0.71       758
# weighted avg       0.95      0.94      0.94       758
#
# ROC-AUC = 0.881		AP = 0.577
# ----------------------------------------------------
# flu
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.95      0.96       714
#         True       0.35      0.43      0.39        44
#
#     accuracy                           0.92       758
#    macro avg       0.66      0.69      0.67       758
# weighted avg       0.93      0.92      0.92       758
#
# ROC-AUC = 0.864		AP = 0.449
# ----------------------------------------------------
# gac
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.86      0.91       660
#         True       0.46      0.81      0.58        98
#
#     accuracy                           0.85       758
#    macro avg       0.71      0.83      0.75       758
# weighted avg       0.90      0.85      0.87       758
#
# ROC-AUC = 0.941		AP = 0.800
# ----------------------------------------------------
# gel
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.89      0.87      0.88       628
#         True       0.45      0.50      0.47       130
#
#     accuracy                           0.81       758
#    macro avg       0.67      0.69      0.68       758
# weighted avg       0.82      0.81      0.81       758
#
# ROC-AUC = 0.790		AP = 0.485
# ----------------------------------------------------
# org
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.76      0.85       684
#         True       0.28      0.86      0.42        74
#
#     accuracy                           0.77       758
#    macro avg       0.63      0.81      0.64       758
# weighted avg       0.91      0.77      0.81       758
#
# ROC-AUC = 0.921		AP = 0.712
# ----------------------------------------------------
# pia
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.97      0.98       719
#         True       0.56      0.72      0.63        39
#
#     accuracy                           0.96       758
#    macro avg       0.77      0.84      0.80       758
# weighted avg       0.96      0.96      0.96       758
#
# ROC-AUC = 0.931		AP = 0.625
# ----------------------------------------------------
# sax
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.93      0.95       723
#         True       0.21      0.37      0.27        35
#
#     accuracy                           0.91       758
#    macro avg       0.59      0.65      0.61       758
# weighted avg       0.93      0.91      0.92       758
#
# ROC-AUC = 0.747		AP = 0.269
# ----------------------------------------------------
# tru
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       717
#         True       0.62      0.78      0.69        41
#
#     accuracy                           0.96       758
#    macro avg       0.80      0.88      0.83       758
# weighted avg       0.97      0.96      0.96       758
#
# ROC-AUC = 0.961		AP = 0.775
# ----------------------------------------------------
# vio
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.98      0.83      0.90       712
#         True       0.20      0.67      0.31        46
#
#     accuracy                           0.82       758
#    macro avg       0.59      0.75      0.60       758
# weighted avg       0.93      0.82      0.86       758
#
# ROC-AUC = 0.841		AP = 0.533
# ----------------------------------------------------
# voi
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.95      0.95       572
#         True       0.84      0.84      0.84       186
#
#     accuracy                           0.92       758
#    macro avg       0.89      0.90      0.90       758
# weighted avg       0.92      0.92      0.92       758
#
# ROC-AUC = 0.960		AP = 0.918

# %% [markdown]
# # save result

# %%
# save all result into a csv file
# result_all.to_csv('results/result_' + embedding + debias_method + '_trainboth.csv', index=False)
# result_all.to_csv('results/result_' + embedding +  debias_method + '.csv', index=False)

# %%
# save all result into a csv file
df_1 = pd.read_csv('results/result_' + embedding + '.csv')

df = df_1.append(result_all)
df.to_csv('results/result_' + embedding  + debias_method + '.csv', index=False)

df = pd.read_csv('results/result_' + embedding  + debias_method + '.csv')

sns.set_theme(context='notebook', style='whitegrid', palette='deep')

sns.catplot(data=df, row='train_set', col='test_set', y='instrument', x='roc_auc', hue='embedding', kind='bar', 
            height=4, aspect=1.2)
plt.xlim([0.4,1])
plt.savefig('results/' + embedding  + debias_method + '.pdf')
